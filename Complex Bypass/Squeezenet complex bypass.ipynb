# %%
import keras
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import h5py

from tensorflow.keras import Model, Sequential

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Concatenate, Convolution2D, GlobalAveragePooling2D, Layer, Add, MaxPool2D

from keras.callbacks import TensorBoard

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras import regularizers

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# We import the training and validation data

# %%
train_dir = '../imagenet2/imagenet2/train'
val_dir = '../imagenet2/imagenet2/val'

batch_size=64
def random_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = np.random.randint(0, h - crop_size + 1)
    left = np.random.randint(0, w - crop_size + 1)
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped

train_datagen = ImageDataGenerator(
    rescale=1.,
    horizontal_flip=True,
    preprocessing_function=random_crop_preprocessing
)


def center_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = (h - crop_size) // 2
    left = (w - crop_size) // 2
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped

val_datagen = ImageDataGenerator(
    rescale=1.,
    preprocessing_function=center_crop_preprocessing
)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator1 = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 9559 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.

# %% [markdown]
# We define the Squeezenet class with complex bypass

# %%
ONE   = (1,1)
THREE = (3,3)
SEVEN = (7,7)


def fire_module(x, squeeze_filters, expand_filters, layer_name_prefix="fire"):

    sq = Conv2D(squeeze_filters, ONE, padding='valid',
                activation='relu', name=f"{layer_name_prefix}_squeeze")(x)

    expand_1x1 = Conv2D(expand_filters//2, ONE, padding='valid',
                        activation='relu', name=f"{layer_name_prefix}_expand1x1")(sq)
    expand_3x3 = Conv2D(expand_filters//2, THREE, padding='same',
                        activation='relu', name=f"{layer_name_prefix}_expand3x3")(sq)

    c = Concatenate(name=f"{layer_name_prefix}_concat")([expand_1x1, expand_3x3])
    return c

def conv1x1_skip(source, out_channels, name="skip_1x1"):
    return Conv2D(out_channels, kernel_size=ONE, strides=(1,1),
                  padding='valid', activation=None,
                  name=name)(source)

def add_bypass(source, target, force_1x1=False, out_channels=None, name="bypass"):
    s_shape = source.shape
    t_shape = target.shape
    if force_1x1:
        if out_channels is None:
            out_channels = t_shape[-1]
        s_conv = conv1x1_skip(source, out_channels=out_channels, name=f"{name}_1x1")
        return Add(name=name)([s_conv, target])
    else:
        if s_shape == t_shape:
            return Add(name=name)([source, target])
        else:
            outc = t_shape[-1]
            s_conv = conv1x1_skip(source, out_channels=outc, name=f"{name}_1x1auto")
            return Add(name=name)([s_conv, target])

def build_squeezenet_complex_bypass(input_shape=(224,224,3), n_classes=10):

    inp = Input(shape=input_shape, name="input")

    x = Conv2D(96, SEVEN, strides=2, padding='same', activation='relu', name='conv1')(inp)
    mp1 = MaxPooling2D(pool_size=THREE, strides=2, name='maxpool1')(x)

    f2 = fire_module(mp1, squeeze_filters=16, expand_filters=128, layer_name_prefix="fire2")

    skip_1_3 = add_bypass(mp1, f2, force_1x1=True, out_channels=128, name="bypass_mp1_f3")
    f3 = fire_module(skip_1_3, squeeze_filters=16, expand_filters=128, layer_name_prefix="fire3")

    skip_2_4 = add_bypass(f2, f3, force_1x1=False, name="bypass_f2_f4_in")
    f4 = fire_module(skip_2_4, squeeze_filters=32, expand_filters=256, layer_name_prefix="fire4")

    skip_3_mp2 = add_bypass(f3, f4, force_1x1=True, out_channels=256, name="bypass_f3_mp2")
    mp2 = MaxPooling2D(pool_size=THREE, strides=2, name='maxpool2')(skip_3_mp2)

    f5 = fire_module(mp2, squeeze_filters=32, expand_filters=256, layer_name_prefix="fire5")

    skip_mp2_6 = add_bypass(mp2, f5, force_1x1=False, name="bypass_mp2_f6_in")
    f6 = fire_module(skip_mp2_6, squeeze_filters=48, expand_filters=384, layer_name_prefix="fire6")

    skip_5_7 = add_bypass(f5, f6, force_1x1=True, out_channels=384, name="bypass_f5_f7_in")
    f7 = fire_module(skip_5_7, squeeze_filters=48, expand_filters=384, layer_name_prefix="fire7")

    skip_6_8 = add_bypass(f6, f7, force_1x1=False, name="bypass_f6_f8_in")
    f8 = fire_module(skip_6_8, squeeze_filters=64, expand_filters=512, layer_name_prefix="fire8")

    skip_7_mp3 = add_bypass(f7, f8, force_1x1=True, out_channels=512, name="bypass_f7_mp3")
    mp3 = MaxPooling2D(pool_size=THREE, strides=2, name='maxpool3')(skip_7_mp3)

    f9 = fire_module(mp3, squeeze_filters=64, expand_filters=512, layer_name_prefix="fire9")

    skip_mp3_10 = add_bypass(mp3, f9, force_1x1=False, name="bypass_mp3_conv10_in")

    drop = Dropout(0.5, name="dropout")(skip_mp3_10)

    conv10 = Conv2D(n_classes, ONE, padding='valid', activation='relu',
                    name='conv10')(drop)
    gap = GlobalAveragePooling2D(name='global_avgpool')(conv10)
    out = Activation('softmax', name='softmax')(gap)

    model = Model(inputs=inp, outputs=out, name="SqueezeNet_ComplexBypass_Figure2")
    return model

# %% [markdown]
# We define the training parameters

# %%
base_lr=0.0003
batch_size=64
steps_per_epoch = train_generator.samples // batch_size
total_epochs = 50

def poly_lr_scheduler(epoch, lr):
    decay = 1.0 - (epoch / total_epochs)
    new_lr = base_lr * decay
    return new_lr

lr_callback = LearningRateScheduler(poly_lr_scheduler)
tensorboard_callback = TensorBoard(log_dir='./logs')
checkpoint_callback = ModelCheckpoint(
    filepath="squeezenet_bypass_checkpoint_epoch_{epoch:02d}.h5",
    save_freq='epoch',
    verbose=1
)

checkpoint_callback = ModelCheckpoint(
    filepath="SqueezeNet_bypass_epoch_{epoch:02d}.h5",
    save_freq='epoch',
    verbose=1
)

# %%
model_complex = build_squeezenet_complex_bypass(input_shape=(224,224,3), n_classes=10)
model_complex.summary()
# Out:
# Model: "SqueezeNet_ComplexBypass_Figure2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 112, 112, 96  14208       ['input[0][0]']
#                                 )
#
#  maxpool1 (MaxPooling2D)        (None, 55, 55, 96)   0           ['conv1[0][0]']
#
#  fire2_squeeze (Conv2D)         (None, 55, 55, 16)   1552        ['maxpool1[0][0]']
#
#  fire2_expand1x1 (Conv2D)       (None, 55, 55, 64)   1088        ['fire2_squeeze[0][0]']
#
#  fire2_expand3x3 (Conv2D)       (None, 55, 55, 64)   9280        ['fire2_squeeze[0][0]']
#
#  bypass_mp1_f3_1x1 (Conv2D)     (None, 55, 55, 128)  12416       ['maxpool1[0][0]']
#
#  fire2_concat (Concatenate)     (None, 55, 55, 128)  0           ['fire2_expand1x1[0][0]',
#                                                                   'fire2_expand3x3[0][0]']
#
#  bypass_mp1_f3 (Add)            (None, 55, 55, 128)  0           ['bypass_mp1_f3_1x1[0][0]',
#                                                                   'fire2_concat[0][0]']
#
#  fire3_squeeze (Conv2D)         (None, 55, 55, 16)   2064        ['bypass_mp1_f3[0][0]']
#
#  fire3_expand1x1 (Conv2D)       (None, 55, 55, 64)   1088        ['fire3_squeeze[0][0]']
#
#  fire3_expand3x3 (Conv2D)       (None, 55, 55, 64)   9280        ['fire3_squeeze[0][0]']
#
#  fire3_concat (Concatenate)     (None, 55, 55, 128)  0           ['fire3_expand1x1[0][0]',
#                                                                   'fire3_expand3x3[0][0]']
#
#  bypass_f2_f4_in (Add)          (None, 55, 55, 128)  0           ['fire2_concat[0][0]',
#                                                                   'fire3_concat[0][0]']
#
#  fire4_squeeze (Conv2D)         (None, 55, 55, 32)   4128        ['bypass_f2_f4_in[0][0]']
#
#  fire4_expand1x1 (Conv2D)       (None, 55, 55, 128)  4224        ['fire4_squeeze[0][0]']
#
#  fire4_expand3x3 (Conv2D)       (None, 55, 55, 128)  36992       ['fire4_squeeze[0][0]']
#
#  bypass_f3_mp2_1x1 (Conv2D)     (None, 55, 55, 256)  33024       ['fire3_concat[0][0]']
#
#  fire4_concat (Concatenate)     (None, 55, 55, 256)  0           ['fire4_expand1x1[0][0]',
#                                                                   'fire4_expand3x3[0][0]']
#
#  bypass_f3_mp2 (Add)            (None, 55, 55, 256)  0           ['bypass_f3_mp2_1x1[0][0]',
#                                                                   'fire4_concat[0][0]']
#
#  maxpool2 (MaxPooling2D)        (None, 27, 27, 256)  0           ['bypass_f3_mp2[0][0]']
#
#  fire5_squeeze (Conv2D)         (None, 27, 27, 32)   8224        ['maxpool2[0][0]']
#
#  fire5_expand1x1 (Conv2D)       (None, 27, 27, 128)  4224        ['fire5_squeeze[0][0]']
#
#  fire5_expand3x3 (Conv2D)       (None, 27, 27, 128)  36992       ['fire5_squeeze[0][0]']
#
#  fire5_concat (Concatenate)     (None, 27, 27, 256)  0           ['fire5_expand1x1[0][0]',
#                                                                   'fire5_expand3x3[0][0]']
#
#  bypass_mp2_f6_in (Add)         (None, 27, 27, 256)  0           ['maxpool2[0][0]',
#                                                                   'fire5_concat[0][0]']
#
#  fire6_squeeze (Conv2D)         (None, 27, 27, 48)   12336       ['bypass_mp2_f6_in[0][0]']
#
#  fire6_expand1x1 (Conv2D)       (None, 27, 27, 192)  9408        ['fire6_squeeze[0][0]']
#
#  fire6_expand3x3 (Conv2D)       (None, 27, 27, 192)  83136       ['fire6_squeeze[0][0]']
#
#  bypass_f5_f7_in_1x1 (Conv2D)   (None, 27, 27, 384)  98688       ['fire5_concat[0][0]']
#
#  fire6_concat (Concatenate)     (None, 27, 27, 384)  0           ['fire6_expand1x1[0][0]',
#                                                                   'fire6_expand3x3[0][0]']
#
#  bypass_f5_f7_in (Add)          (None, 27, 27, 384)  0           ['bypass_f5_f7_in_1x1[0][0]',
#                                                                   'fire6_concat[0][0]']
#
#  fire7_squeeze (Conv2D)         (None, 27, 27, 48)   18480       ['bypass_f5_f7_in[0][0]']
#
#  fire7_expand1x1 (Conv2D)       (None, 27, 27, 192)  9408        ['fire7_squeeze[0][0]']
#
#  fire7_expand3x3 (Conv2D)       (None, 27, 27, 192)  83136       ['fire7_squeeze[0][0]']
#
#  fire7_concat (Concatenate)     (None, 27, 27, 384)  0           ['fire7_expand1x1[0][0]',
#                                                                   'fire7_expand3x3[0][0]']
#
#  bypass_f6_f8_in (Add)          (None, 27, 27, 384)  0           ['fire6_concat[0][0]',
#                                                                   'fire7_concat[0][0]']
#
#  fire8_squeeze (Conv2D)         (None, 27, 27, 64)   24640       ['bypass_f6_f8_in[0][0]']
#
#  fire8_expand1x1 (Conv2D)       (None, 27, 27, 256)  16640       ['fire8_squeeze[0][0]']
#
#  fire8_expand3x3 (Conv2D)       (None, 27, 27, 256)  147712      ['fire8_squeeze[0][0]']
#
#  bypass_f7_mp3_1x1 (Conv2D)     (None, 27, 27, 512)  197120      ['fire7_concat[0][0]']
#
#  fire8_concat (Concatenate)     (None, 27, 27, 512)  0           ['fire8_expand1x1[0][0]',
#                                                                   'fire8_expand3x3[0][0]']
#
#  bypass_f7_mp3 (Add)            (None, 27, 27, 512)  0           ['bypass_f7_mp3_1x1[0][0]',
#                                                                   'fire8_concat[0][0]']
#
#  maxpool3 (MaxPooling2D)        (None, 13, 13, 512)  0           ['bypass_f7_mp3[0][0]']
#
#  fire9_squeeze (Conv2D)         (None, 13, 13, 64)   32832       ['maxpool3[0][0]']
#
#  fire9_expand1x1 (Conv2D)       (None, 13, 13, 256)  16640       ['fire9_squeeze[0][0]']
#
#  fire9_expand3x3 (Conv2D)       (None, 13, 13, 256)  147712      ['fire9_squeeze[0][0]']
#
#  fire9_concat (Concatenate)     (None, 13, 13, 512)  0           ['fire9_expand1x1[0][0]',
#                                                                   'fire9_expand3x3[0][0]']
#
#  bypass_mp3_conv10_in (Add)     (None, 13, 13, 512)  0           ['maxpool3[0][0]',
#                                                                   'fire9_concat[0][0]']
#
#  dropout (Dropout)              (None, 13, 13, 512)  0           ['bypass_mp3_conv10_in[0][0]']
#
#  conv10 (Conv2D)                (None, 13, 13, 10)   5130        ['dropout[0][0]']
#
#  global_avgpool (GlobalAverageP  (None, 10)          0           ['conv10[0][0]']
#  ooling2D)
#
#  softmax (Activation)           (None, 10)           0           ['global_avgpool[0][0]']
#
# ==================================================================================================
# Total params: 1,081,802
# Trainable params: 1,081,802
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# We train the Squeezenet model with complex bypass

# %%
model_complex.compile(optimizer= tf.keras.optimizers.Adam(base_lr),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

sq_bypass_history = model_complex.fit(
    train_generator,
    epochs=total_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size,
    callbacks=[lr_callback, checkpoint_callback, tensorboard_callback],
    verbose=1
)
# Out:
# Epoch 1/50
# 149/149 [==============================] - ETA: 0s - loss: 2.2406 - accuracy: 0.1738
# Epoch 1: saving model to SqueezeNet_bypass_epoch_01.h5
# 149/149 [==============================] - 619s 4s/step - loss: 2.2406 - accuracy: 0.1738 - val_loss: 2.2071 - val_accuracy: 0.1614 - lr: 3.0000e-04
# Epoch 2/50
# 149/149 [==============================] - ETA: 0s - loss: 2.1615 - accuracy: 0.2063
# Epoch 2: saving model to SqueezeNet_bypass_epoch_02.h5
# 149/149 [==============================] - 530s 4s/step - loss: 2.1615 - accuracy: 0.2063 - val_loss: 2.1233 - val_accuracy: 0.2405 - lr: 2.9400e-04
# Epoch 3/50
# 149/149 [==============================] - ETA: 0s - loss: 2.0630 - accuracy: 0.2758
# Epoch 3: saving model to SqueezeNet_bypass_epoch_03.h5
# 149/149 [==============================] - 505s 3s/step - loss: 2.0630 - accuracy: 0.2758 - val_loss: 2.0370 - val_accuracy: 0.2999 - lr: 2.8800e-04
# Epoch 4/50
# 149/149 [==============================] - ETA: 0s - loss: 1.9082 - accuracy: 0.3699
# Epoch 4: saving model to SqueezeNet_bypass_epoch_04.h5
# 149/149 [==============================] - 495s 3s/step - loss: 1.9082 - accuracy: 0.3699 - val_loss: 1.8674 - val_accuracy: 0.3827 - lr: 2.8200e-04
# Epoch 5/50
# 149/149 [==============================] - ETA: 0s - loss: 1.6802 - accuracy: 0.4538
# Epoch 5: saving model to SqueezeNet_bypass_epoch_05.h5
# 149/149 [==============================] - 485s 3s/step - loss: 1.6802 - accuracy: 0.4538 - val_loss: 1.5946 - val_accuracy: 0.5077 - lr: 2.7600e-04
# Epoch 6/50
# 149/149 [==============================] - ETA: 0s - loss: 1.4934 - accuracy: 0.5264
# Epoch 6: saving model to SqueezeNet_bypass_epoch_06.h5
# 149/149 [==============================] - 502s 3s/step - loss: 1.4934 - accuracy: 0.5264 - val_loss: 1.5914 - val_accuracy: 0.4872 - lr: 2.7000e-04
# Epoch 7/50
# 149/149 [==============================] - ETA: 0s - loss: 1.4071 - accuracy: 0.5533
# Epoch 7: saving model to SqueezeNet_bypass_epoch_07.h5
# 149/149 [==============================] - 537s 4s/step - loss: 1.4071 - accuracy: 0.5533 - val_loss: 1.3102 - val_accuracy: 0.5899 - lr: 2.6400e-04
# Epoch 8/50
# 149/149 [==============================] - ETA: 0s - loss: 1.2719 - accuracy: 0.5953
# Epoch 8: saving model to SqueezeNet_bypass_epoch_08.h5
# 149/149 [==============================] - 521s 3s/step - loss: 1.2719 - accuracy: 0.5953 - val_loss: 1.1692 - val_accuracy: 0.6404 - lr: 2.5800e-04
# Epoch 9/50
# 149/149 [==============================] - ETA: 0s - loss: 1.0670 - accuracy: 0.6580
# Epoch 9: saving model to SqueezeNet_bypass_epoch_09.h5
# 149/149 [==============================] - 525s 4s/step - loss: 1.0670 - accuracy: 0.6580 - val_loss: 0.9970 - val_accuracy: 0.6947 - lr: 2.5200e-04
# Epoch 10/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9634 - accuracy: 0.6944
# Epoch 10: saving model to SqueezeNet_bypass_epoch_10.h5
# 149/149 [==============================] - 531s 4s/step - loss: 0.9634 - accuracy: 0.6944 - val_loss: 1.1878 - val_accuracy: 0.6311 - lr: 2.4600e-04
# Epoch 11/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9121 - accuracy: 0.7100
# Epoch 11: saving model to SqueezeNet_bypass_epoch_11.h5
# 149/149 [==============================] - 526s 4s/step - loss: 0.9121 - accuracy: 0.7100 - val_loss: 1.0870 - val_accuracy: 0.6616 - lr: 2.4000e-04
# Epoch 12/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8601 - accuracy: 0.7279
# Epoch 12: saving model to SqueezeNet_bypass_epoch_12.h5
# 149/149 [==============================] - 524s 4s/step - loss: 0.8601 - accuracy: 0.7279 - val_loss: 0.8740 - val_accuracy: 0.7226 - lr: 2.3400e-04
# Epoch 13/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7923 - accuracy: 0.7507
# Epoch 13: saving model to SqueezeNet_bypass_epoch_13.h5
# 149/149 [==============================] - 548s 4s/step - loss: 0.7923 - accuracy: 0.7507 - val_loss: 0.8364 - val_accuracy: 0.7400 - lr: 2.2800e-04
# Epoch 14/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7485 - accuracy: 0.7639
# Epoch 14: saving model to SqueezeNet_bypass_epoch_14.h5
# 149/149 [==============================] - 545s 4s/step - loss: 0.7485 - accuracy: 0.7639 - val_loss: 0.8665 - val_accuracy: 0.7380 - lr: 2.2200e-04
# Epoch 15/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7227 - accuracy: 0.7732
# Epoch 15: saving model to SqueezeNet_bypass_epoch_15.h5
# 149/149 [==============================] - 530s 4s/step - loss: 0.7227 - accuracy: 0.7732 - val_loss: 0.8482 - val_accuracy: 0.7262 - lr: 2.1600e-04
# Epoch 16/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7139 - accuracy: 0.7777
# Epoch 16: saving model to SqueezeNet_bypass_epoch_16.h5
# 149/149 [==============================] - 517s 3s/step - loss: 0.7139 - accuracy: 0.7777 - val_loss: 0.8987 - val_accuracy: 0.7162 - lr: 2.1000e-04
# Epoch 17/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6629 - accuracy: 0.7872
# Epoch 17: saving model to SqueezeNet_bypass_epoch_17.h5
# 149/149 [==============================] - 481s 3s/step - loss: 0.6629 - accuracy: 0.7872 - val_loss: 0.7622 - val_accuracy: 0.7674 - lr: 2.0400e-04
# Epoch 18/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6255 - accuracy: 0.7999
# Epoch 18: saving model to SqueezeNet_bypass_epoch_18.h5
# 149/149 [==============================] - 438s 3s/step - loss: 0.6255 - accuracy: 0.7999 - val_loss: 0.9314 - val_accuracy: 0.7188 - lr: 1.9800e-04
# Epoch 19/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6206 - accuracy: 0.8034
# Epoch 19: saving model to SqueezeNet_bypass_epoch_19.h5
# 149/149 [==============================] - 440s 3s/step - loss: 0.6206 - accuracy: 0.8034 - val_loss: 0.7765 - val_accuracy: 0.7651 - lr: 1.9200e-04
# Epoch 20/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.8173
# Epoch 20: saving model to SqueezeNet_bypass_epoch_20.h5
# 149/149 [==============================] - 484s 3s/step - loss: 0.5838 - accuracy: 0.8173 - val_loss: 0.7561 - val_accuracy: 0.7769 - lr: 1.8600e-04
# Epoch 21/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5507 - accuracy: 0.8237
# Epoch 21: saving model to SqueezeNet_bypass_epoch_21.h5
# 149/149 [==============================] - 489s 3s/step - loss: 0.5507 - accuracy: 0.8237 - val_loss: 0.6990 - val_accuracy: 0.7943 - lr: 1.8000e-04
# Epoch 22/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5294 - accuracy: 0.8324
# Epoch 22: saving model to SqueezeNet_bypass_epoch_22.h5
# 149/149 [==============================] - 506s 3s/step - loss: 0.5294 - accuracy: 0.8324 - val_loss: 0.7572 - val_accuracy: 0.7751 - lr: 1.7400e-04
# Epoch 23/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4993 - accuracy: 0.8404
# Epoch 23: saving model to SqueezeNet_bypass_epoch_23.h5
# 149/149 [==============================] - 543s 4s/step - loss: 0.4993 - accuracy: 0.8404 - val_loss: 0.7556 - val_accuracy: 0.7741 - lr: 1.6800e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4774 - accuracy: 0.8478
# Epoch 24: saving model to SqueezeNet_bypass_epoch_24.h5
# 149/149 [==============================] - 568s 4s/step - loss: 0.4774 - accuracy: 0.8478 - val_loss: 0.7060 - val_accuracy: 0.7861 - lr: 1.6200e-04
# Epoch 25/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4516 - accuracy: 0.8589
# Epoch 25: saving model to SqueezeNet_bypass_epoch_25.h5
# 149/149 [==============================] - 574s 4s/step - loss: 0.4516 - accuracy: 0.8589 - val_loss: 0.7458 - val_accuracy: 0.7841 - lr: 1.5600e-04
# Epoch 26/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8621
# Epoch 26: saving model to SqueezeNet_bypass_epoch_26.h5
# 149/149 [==============================] - 563s 4s/step - loss: 0.4324 - accuracy: 0.8621 - val_loss: 0.7443 - val_accuracy: 0.7684 - lr: 1.5000e-04
# Epoch 27/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.8616
# Epoch 27: saving model to SqueezeNet_bypass_epoch_27.h5
# 149/149 [==============================] - 560s 4s/step - loss: 0.4248 - accuracy: 0.8616 - val_loss: 0.7111 - val_accuracy: 0.7889 - lr: 1.4400e-04
# Epoch 28/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8766
# Epoch 28: saving model to SqueezeNet_bypass_epoch_28.h5
# 149/149 [==============================] - 540s 4s/step - loss: 0.3907 - accuracy: 0.8766 - val_loss: 0.6937 - val_accuracy: 0.7946 - lr: 1.3800e-04
# Epoch 29/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.8791
# Epoch 29: saving model to SqueezeNet_bypass_epoch_29.h5
# 149/149 [==============================] - 549s 4s/step - loss: 0.3707 - accuracy: 0.8791 - val_loss: 0.8007 - val_accuracy: 0.7789 - lr: 1.3200e-04
# Epoch 30/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3514 - accuracy: 0.8850
# Epoch 30: saving model to SqueezeNet_bypass_epoch_30.h5
# 149/149 [==============================] - 545s 4s/step - loss: 0.3514 - accuracy: 0.8850 - val_loss: 0.7306 - val_accuracy: 0.7905 - lr: 1.2600e-04
# Epoch 31/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.9005
# Epoch 31: saving model to SqueezeNet_bypass_epoch_31.h5
# 149/149 [==============================] - 521s 3s/step - loss: 0.3169 - accuracy: 0.9005 - val_loss: 0.7119 - val_accuracy: 0.7964 - lr: 1.2000e-04
# Epoch 32/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.9047
# Epoch 32: saving model to SqueezeNet_bypass_epoch_32.h5
# 149/149 [==============================] - 496s 3s/step - loss: 0.3022 - accuracy: 0.9047 - val_loss: 0.7070 - val_accuracy: 0.8051 - lr: 1.1400e-04
# Epoch 33/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2813 - accuracy: 0.9102
# Epoch 33: saving model to SqueezeNet_bypass_epoch_33.h5
# 149/149 [==============================] - 494s 3s/step - loss: 0.2813 - accuracy: 0.9102 - val_loss: 0.7106 - val_accuracy: 0.8094 - lr: 1.0800e-04
# Epoch 34/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.9185
# Epoch 34: saving model to SqueezeNet_bypass_epoch_34.h5
# 149/149 [==============================] - 499s 3s/step - loss: 0.2616 - accuracy: 0.9185 - val_loss: 0.7424 - val_accuracy: 0.7918 - lr: 1.0200e-04
# Epoch 35/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2506 - accuracy: 0.9205
# Epoch 35: saving model to SqueezeNet_bypass_epoch_35.h5
# 149/149 [==============================] - 505s 3s/step - loss: 0.2506 - accuracy: 0.9205 - val_loss: 0.7565 - val_accuracy: 0.8071 - lr: 9.6000e-05
# Epoch 36/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9284
# Epoch 36: saving model to SqueezeNet_bypass_epoch_36.h5
# 149/149 [==============================] - 500s 3s/step - loss: 0.2237 - accuracy: 0.9284 - val_loss: 0.7870 - val_accuracy: 0.7948 - lr: 9.0000e-05
# Epoch 37/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2282 - accuracy: 0.9285
# Epoch 37: saving model to SqueezeNet_bypass_epoch_37.h5
# 149/149 [==============================] - 494s 3s/step - loss: 0.2282 - accuracy: 0.9285 - val_loss: 0.7724 - val_accuracy: 0.8007 - lr: 8.4000e-05
# Epoch 38/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9343
# Epoch 38: saving model to SqueezeNet_bypass_epoch_38.h5
# 149/149 [==============================] - 503s 3s/step - loss: 0.2051 - accuracy: 0.9343 - val_loss: 0.8295 - val_accuracy: 0.7892 - lr: 7.8000e-05
# Epoch 39/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9429
# Epoch 39: saving model to SqueezeNet_bypass_epoch_39.h5
# 149/149 [==============================] - 520s 3s/step - loss: 0.1867 - accuracy: 0.9429 - val_loss: 0.7705 - val_accuracy: 0.8015 - lr: 7.2000e-05
# Epoch 40/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9452
# Epoch 40: saving model to SqueezeNet_bypass_epoch_40.h5
# 149/149 [==============================] - 557s 4s/step - loss: 0.1755 - accuracy: 0.9452 - val_loss: 0.8212 - val_accuracy: 0.8089 - lr: 6.6000e-05
# Epoch 41/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9536
# Epoch 41: saving model to SqueezeNet_bypass_epoch_41.h5
# 149/149 [==============================] - 552s 4s/step - loss: 0.1538 - accuracy: 0.9536 - val_loss: 0.7988 - val_accuracy: 0.8064 - lr: 6.0000e-05
# Epoch 42/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9563
# Epoch 42: saving model to SqueezeNet_bypass_epoch_42.h5
# 149/149 [==============================] - 539s 4s/step - loss: 0.1427 - accuracy: 0.9563 - val_loss: 0.8025 - val_accuracy: 0.8099 - lr: 5.4000e-05
# Epoch 43/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9601
# Epoch 43: saving model to SqueezeNet_bypass_epoch_43.h5
# 149/149 [==============================] - 538s 4s/step - loss: 0.1347 - accuracy: 0.9601 - val_loss: 0.8113 - val_accuracy: 0.8089 - lr: 4.8000e-05
# Epoch 44/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9645
# Epoch 44: saving model to SqueezeNet_bypass_epoch_44.h5
# 149/149 [==============================] - 539s 4s/step - loss: 0.1193 - accuracy: 0.9645 - val_loss: 0.8582 - val_accuracy: 0.8035 - lr: 4.2000e-05
# Epoch 45/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9682
# Epoch 45: saving model to SqueezeNet_bypass_epoch_45.h5
# 149/149 [==============================] - 548s 4s/step - loss: 0.1067 - accuracy: 0.9682 - val_loss: 0.8838 - val_accuracy: 0.8125 - lr: 3.6000e-05
# Epoch 46/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9722
# Epoch 46: saving model to SqueezeNet_bypass_epoch_46.h5
# 149/149 [==============================] - 539s 4s/step - loss: 0.0964 - accuracy: 0.9722 - val_loss: 0.8632 - val_accuracy: 0.8112 - lr: 3.0000e-05
# Epoch 47/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9755
# Epoch 47: saving model to SqueezeNet_bypass_epoch_47.h5
# 149/149 [==============================] - 533s 4s/step - loss: 0.0899 - accuracy: 0.9755 - val_loss: 0.8881 - val_accuracy: 0.8066 - lr: 2.4000e-05
# Epoch 48/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9762
# Epoch 48: saving model to SqueezeNet_bypass_epoch_48.h5
# 149/149 [==============================] - 535s 4s/step - loss: 0.0853 - accuracy: 0.9762 - val_loss: 0.9111 - val_accuracy: 0.8115 - lr: 1.8000e-05
# Epoch 49/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9806
# Epoch 49: saving model to SqueezeNet_bypass_epoch_49.h5
# 149/149 [==============================] - 528s 4s/step - loss: 0.0779 - accuracy: 0.9806 - val_loss: 0.9223 - val_accuracy: 0.8130 - lr: 1.2000e-05
# Epoch 50/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9824
# Epoch 50: saving model to SqueezeNet_bypass_epoch_50.h5
# 149/149 [==============================] - 527s 4s/step - loss: 0.0727 - accuracy: 0.9824 - val_loss: 0.8941 - val_accuracy: 0.8138 - lr: 6.0000e-06

# %%
model_complex.summary()
# Out:
# Model: "SqueezeNet_ComplexBypass_Figure2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 112, 112, 96  14208       ['input[0][0]']
#                                 )
#
#  maxpool1 (MaxPooling2D)        (None, 55, 55, 96)   0           ['conv1[0][0]']
#
#  fire2_squeeze (Conv2D)         (None, 55, 55, 16)   1552        ['maxpool1[0][0]']
#
#  fire2_expand1x1 (Conv2D)       (None, 55, 55, 64)   1088        ['fire2_squeeze[0][0]']
#
#  fire2_expand3x3 (Conv2D)       (None, 55, 55, 64)   9280        ['fire2_squeeze[0][0]']
#
#  bypass_mp1_f3_1x1 (Conv2D)     (None, 55, 55, 128)  12416       ['maxpool1[0][0]']
#
#  fire2_concat (Concatenate)     (None, 55, 55, 128)  0           ['fire2_expand1x1[0][0]',
#                                                                   'fire2_expand3x3[0][0]']
#
#  bypass_mp1_f3 (Add)            (None, 55, 55, 128)  0           ['bypass_mp1_f3_1x1[0][0]',
#                                                                   'fire2_concat[0][0]']
#
#  fire3_squeeze (Conv2D)         (None, 55, 55, 16)   2064        ['bypass_mp1_f3[0][0]']
#
#  fire3_expand1x1 (Conv2D)       (None, 55, 55, 64)   1088        ['fire3_squeeze[0][0]']
#
#  fire3_expand3x3 (Conv2D)       (None, 55, 55, 64)   9280        ['fire3_squeeze[0][0]']
#
#  fire3_concat (Concatenate)     (None, 55, 55, 128)  0           ['fire3_expand1x1[0][0]',
#                                                                   'fire3_expand3x3[0][0]']
#
#  bypass_f2_f4_in (Add)          (None, 55, 55, 128)  0           ['fire2_concat[0][0]',
#                                                                   'fire3_concat[0][0]']
#
#  fire4_squeeze (Conv2D)         (None, 55, 55, 32)   4128        ['bypass_f2_f4_in[0][0]']
#
#  fire4_expand1x1 (Conv2D)       (None, 55, 55, 128)  4224        ['fire4_squeeze[0][0]']
#
#  fire4_expand3x3 (Conv2D)       (None, 55, 55, 128)  36992       ['fire4_squeeze[0][0]']
#
#  bypass_f3_mp2_1x1 (Conv2D)     (None, 55, 55, 256)  33024       ['fire3_concat[0][0]']
#
#  fire4_concat (Concatenate)     (None, 55, 55, 256)  0           ['fire4_expand1x1[0][0]',
#                                                                   'fire4_expand3x3[0][0]']
#
#  bypass_f3_mp2 (Add)            (None, 55, 55, 256)  0           ['bypass_f3_mp2_1x1[0][0]',
#                                                                   'fire4_concat[0][0]']
#
#  maxpool2 (MaxPooling2D)        (None, 27, 27, 256)  0           ['bypass_f3_mp2[0][0]']
#
#  fire5_squeeze (Conv2D)         (None, 27, 27, 32)   8224        ['maxpool2[0][0]']
#
#  fire5_expand1x1 (Conv2D)       (None, 27, 27, 128)  4224        ['fire5_squeeze[0][0]']
#
#  fire5_expand3x3 (Conv2D)       (None, 27, 27, 128)  36992       ['fire5_squeeze[0][0]']
#
#  fire5_concat (Concatenate)     (None, 27, 27, 256)  0           ['fire5_expand1x1[0][0]',
#                                                                   'fire5_expand3x3[0][0]']
#
#  bypass_mp2_f6_in (Add)         (None, 27, 27, 256)  0           ['maxpool2[0][0]',
#                                                                   'fire5_concat[0][0]']
#
#  fire6_squeeze (Conv2D)         (None, 27, 27, 48)   12336       ['bypass_mp2_f6_in[0][0]']
#
#  fire6_expand1x1 (Conv2D)       (None, 27, 27, 192)  9408        ['fire6_squeeze[0][0]']
#
#  fire6_expand3x3 (Conv2D)       (None, 27, 27, 192)  83136       ['fire6_squeeze[0][0]']
#
#  bypass_f5_f7_in_1x1 (Conv2D)   (None, 27, 27, 384)  98688       ['fire5_concat[0][0]']
#
#  fire6_concat (Concatenate)     (None, 27, 27, 384)  0           ['fire6_expand1x1[0][0]',
#                                                                   'fire6_expand3x3[0][0]']
#
#  bypass_f5_f7_in (Add)          (None, 27, 27, 384)  0           ['bypass_f5_f7_in_1x1[0][0]',
#                                                                   'fire6_concat[0][0]']
#
#  fire7_squeeze (Conv2D)         (None, 27, 27, 48)   18480       ['bypass_f5_f7_in[0][0]']
#
#  fire7_expand1x1 (Conv2D)       (None, 27, 27, 192)  9408        ['fire7_squeeze[0][0]']
#
#  fire7_expand3x3 (Conv2D)       (None, 27, 27, 192)  83136       ['fire7_squeeze[0][0]']
#
#  fire7_concat (Concatenate)     (None, 27, 27, 384)  0           ['fire7_expand1x1[0][0]',
#                                                                   'fire7_expand3x3[0][0]']
#
#  bypass_f6_f8_in (Add)          (None, 27, 27, 384)  0           ['fire6_concat[0][0]',
#                                                                   'fire7_concat[0][0]']
#
#  fire8_squeeze (Conv2D)         (None, 27, 27, 64)   24640       ['bypass_f6_f8_in[0][0]']
#
#  fire8_expand1x1 (Conv2D)       (None, 27, 27, 256)  16640       ['fire8_squeeze[0][0]']
#
#  fire8_expand3x3 (Conv2D)       (None, 27, 27, 256)  147712      ['fire8_squeeze[0][0]']
#
#  bypass_f7_mp3_1x1 (Conv2D)     (None, 27, 27, 512)  197120      ['fire7_concat[0][0]']
#
#  fire8_concat (Concatenate)     (None, 27, 27, 512)  0           ['fire8_expand1x1[0][0]',
#                                                                   'fire8_expand3x3[0][0]']
#
#  bypass_f7_mp3 (Add)            (None, 27, 27, 512)  0           ['bypass_f7_mp3_1x1[0][0]',
#                                                                   'fire8_concat[0][0]']
#
#  maxpool3 (MaxPooling2D)        (None, 13, 13, 512)  0           ['bypass_f7_mp3[0][0]']
#
#  fire9_squeeze (Conv2D)         (None, 13, 13, 64)   32832       ['maxpool3[0][0]']
#
#  fire9_expand1x1 (Conv2D)       (None, 13, 13, 256)  16640       ['fire9_squeeze[0][0]']
#
#  fire9_expand3x3 (Conv2D)       (None, 13, 13, 256)  147712      ['fire9_squeeze[0][0]']
#
#  fire9_concat (Concatenate)     (None, 13, 13, 512)  0           ['fire9_expand1x1[0][0]',
#                                                                   'fire9_expand3x3[0][0]']
#
#  bypass_mp3_conv10_in (Add)     (None, 13, 13, 512)  0           ['maxpool3[0][0]',
#                                                                   'fire9_concat[0][0]']
#
#  dropout (Dropout)              (None, 13, 13, 512)  0           ['bypass_mp3_conv10_in[0][0]']
#
#  conv10 (Conv2D)                (None, 13, 13, 10)   5130        ['dropout[0][0]']
#
#  global_avgpool (GlobalAverageP  (None, 10)          0           ['conv10[0][0]']
#  ooling2D)
#
#  softmax (Activation)           (None, 10)           0           ['global_avgpool[0][0]']
#
# ==================================================================================================
# Total params: 1,081,802
# Trainable params: 1,081,802
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_complex.save_weights('Squeezenet_complex_bypass.h5')

# %%
model_complex_load = build_squeezenet_complex_bypass(input_shape=(224,224,3), n_classes=10)
model_complex_load.load_weights('Squeezenet_complex_bypass.h5')

# %% [markdown]
# We verify the accuracy

# %%
val_steps = val_generator1.samples // batch_size

predictions = model_complex_load.predict(val_generator1, steps=val_steps)

true_labels = val_generator1.classes[:val_steps * batch_size]

num_classes = len(val_generator1.class_indices)
true_labels_one_hot = tf.keras.utils.to_categorical(true_labels, num_classes)

top1_metric = tf.keras.metrics.CategoricalAccuracy()
top5_metric = tf.keras.metrics.TopKCategoricalAccuracy(k=5)
top1_metric.update_state(true_labels_one_hot, predictions)
top5_metric.update_state(true_labels_one_hot, predictions)

print("Top-1 Accuracy on validation set:", top1_metric.result().numpy())
print("Top-5 Accuracy on validation set:", top5_metric.result().numpy())
# Out:
# 61/61 [==============================] - 79s 1s/step
# Top-1 Accuracy on validation set: 0.8145492
# Top-5 Accuracy on validation set: 0.977459
