# %%
import keras
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import h5py

from tensorflow.keras import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Layer, Concatenate, Add, MaxPool2D, GlobalAveragePooling2D, Activation, Convolution2D

from keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.utils import plot_model

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# We import the training and validation data

# %%
train_dir = '../imagenet2/imagenet2/train'
val_dir = '../imagenet2/imagenet2/val'
batch_size=64


def random_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = np.random.randint(0, h - crop_size + 1)
    left = np.random.randint(0, w - crop_size + 1)
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped


train_datagen = ImageDataGenerator(
    rescale=1.,
    horizontal_flip=True,
    preprocessing_function=random_crop_preprocessing
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)

def center_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = (h - crop_size) // 2
    left = (w - crop_size) // 2
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped

val_datagen = ImageDataGenerator(
    rescale=1.,
    preprocessing_function=center_crop_preprocessing
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)
val_generator1 = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 9559 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.

# %% [markdown]
# We define the squeezenet architecture allowing us to vary the squeeze ratio

# %%
one = (1, 1)
three = (3, 3)
seven = (7, 7)

input_shape = (227, 227, 3)
class FireModule(object):

    def __init__(self, layer_number: int, activation: str, kernel_initializer: str,sq=0.125,p3=0.5) -> None:
        self.layer_number = layer_number
        self.activation = activation
        self.kernel_initializer = kernel_initializer
        self.sq=sq
        self.p3=p3

    def build_module(self, fire_input: Layer) -> Layer:
        global one, three

        output_size = 128 * (1 + (self.layer_number//2))

        squeeze_1x1_filters = int(output_size*self.sq)
        expand_1x1_filters = int(output_size*(1-self.p3))
        expand_3x3_filters= int(output_size*self.p3)

        squeeze_1x1 = Conv2D(name=f'fire_{self.layer_number+2}_squeeze_1x1',
            filters=squeeze_1x1_filters, kernel_size=one, strides=1, padding='valid', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(fire_input)
        expand_1x1 = Conv2D(name=f'fire_{self.layer_number+2}_expand_1x1',
            filters=expand_1x1_filters, kernel_size=one, strides=1, padding='valid', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(squeeze_1x1)
        expand_3x3 = Conv2D(name=f'fire_{self.layer_number+2}_expand_3x3',
            filters=expand_3x3_filters, kernel_size=three, strides=1, padding='same', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(squeeze_1x1)

        fire = Concatenate(name=f'fire_{self.layer_number+2}')([expand_1x1, expand_3x3])

        return fire
class SqueezeNet(object):

    def __init__(self, activation: str='relu', kernel_initializer: str='glorot_uniform', squeeze_ratio=0.125, p3=0.5) -> None:
        self.activation = activation
        self.kernel_initializer = kernel_initializer
        self.sq=squeeze_ratio
        self.p3=p3

    def vanilla_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000) -> None:
        inp = Input(shape=input_shape, name='Input')

        conv_1 = Conv2D(name="Conv_1",
            filters=96, kernel_size=seven, strides=2, padding='same', activation=self.activation, kernel_initializer=self.kernel_initializer)(inp)
        maxpool_1 = MaxPool2D(name="MaxPool_1",
            pool_size=three, strides=2)(conv_1)


        fire_2 = FireModule(layer_number=0, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(maxpool_1)
        fire_3 = FireModule(layer_number=1, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(fire_2)
        fire_4 = FireModule(layer_number=2, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(fire_3)


        maxpool_2 = MaxPool2D(name="MaxPool_2",
            pool_size=three, strides=2)(fire_4)

        fire_5 = FireModule(layer_number=3, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(maxpool_2)
        fire_6 = FireModule(layer_number=4, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(fire_5)
        fire_7 = FireModule(layer_number=5, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(fire_6)
        fire_8 = FireModule(layer_number=6, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(fire_7)

        maxpool_3 = MaxPool2D(name="MaxPool_3",
            pool_size=three, strides=2)(fire_8)

        fire_9 = FireModule(layer_number=7, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(maxpool_3)

        dropout = Dropout(0.5, name="Dropout")(fire_9)

        conv_10 = Conv2D(name="Conv_10",
            filters=10, kernel_size=one, strides=1, padding='valid', activation=self.activation, kernel_initializer=self.kernel_initializer)(dropout)
        gap_11 = GlobalAveragePooling2D()(conv_10)
        out = Activation('softmax', name='softmax')(gap_11)

        self.model = Model(inputs=inp, outputs=out)


    def bypass_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000) -> None:

        inp = Input(shape=input_shape, name='Input')

        conv_1 = Conv2D(name="Conv_1",
            filters=96, kernel_size=seven, strides=2, padding='same', activation=self.activation, kernel_initializer=self.kernel_initializer)(inp)
        maxpool_1 = MaxPool2D(name="MaxPool_1",
            pool_size=three, strides=2)(conv_1)

        fire_2 = FireModule(layer_number=0, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(maxpool_1)
        fire_3 = FireModule(layer_number=1, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(fire_2)
        bypass_1 = Add(name="Bypass_1")([fire_2, fire_3])
        fire_4 = FireModule(layer_number=2, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(bypass_1)

        maxpool_2 = MaxPool2D(name="MaxPool_2",
            pool_size=three, strides=2)(fire_4)

        fire_5 = FireModule(layer_number=3, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(maxpool_2)
        bypass_2 = Add(name="Bypass_2")([maxpool_2, fire_5])
        fire_6 = FireModule(layer_number=4, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(bypass_2)
        fire_7 = FireModule(layer_number=5, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(fire_6)
        bypass_3 = Add(name="Bypass_3")([fire_6, fire_7])
        fire_8 = FireModule(layer_number=6, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(bypass_3)

        maxpool_3 = MaxPool2D(name="MaxPool_3",
            pool_size=three, strides=2)(fire_8)

        fire_9 = FireModule(layer_number=7, activation=self.activation, kernel_initializer=self.kernel_initializer,sq=self.sq,p3=self.p3).build_module(maxpool_3)
        bypass_4 = Add(name="Bypass_4")([maxpool_3, fire_9])

        dropout = Dropout(0.5, name="Dropout")(bypass_4)

        conv_10 = Conv2D(name="Conv_10",
            filters=10, kernel_size=one, strides=1, padding='valid', activation=self.activation, kernel_initializer=self.kernel_initializer)(dropout)
        gap_11 = GlobalAveragePooling2D()(conv_10)
        out = Activation('softmax', name='softmax')(gap_11)

        self.model = Model(inputs=inp, outputs=out)


    def build_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000, choice: str='vanilla') -> Model:
        if choice == "vanilla":
            self.vanilla_model(input_shape, n_classes)
        else:
            self.bypass_model(input_shape, n_classes)

        return self.model

# %% [markdown]
# We set up the training parameters

# %%
base_lr=0.0003
batch_size=64
steps_per_epoch = train_generator.samples // batch_size
total_epochs = 50

def poly_lr_scheduler(epoch, lr):
    decay = 1.0 - (epoch / total_epochs)
    new_lr = base_lr * decay
    return new_lr

lr_callback = LearningRateScheduler(poly_lr_scheduler)
tensorboard_callback = TensorBoard(log_dir='./logs')
checkpoint_callback = ModelCheckpoint(
    filepath="squeezenet_bypass_checkpoint_epoch_{epoch:02d}.h5",
    save_freq='epoch',
    verbose=1
)

# %% [markdown]
# We train the models and save the weights

# %%
model_sq_ratio={}
sq_ratio_history={}
sr_list=[0.125,0.25,0.5,0.75,1]
for i in range(len(sr_list)):
    r=sr_list[i]
    print('squeeze ratio is', r)
    sqnet = SqueezeNet(squeeze_ratio=r)
    model =sqnet.build_model(input_shape=input_shape, n_classes=10, choice='bypass')
    model.compile(optimizer= tf.keras.optimizers.Adam(base_lr),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

    checkpoint_callback = ModelCheckpoint(
        filepath="SqueezeNet_sq_ratio_{}_epoch_{{epoch:02d}}.h5".format(r),
        save_freq='epoch',
        verbose=1
    )

    training_history = model.fit(
        train_generator,
        epochs=total_epochs,
        steps_per_epoch=steps_per_epoch,
        validation_data=val_generator,
        validation_steps=val_generator.samples // batch_size,
        callbacks=[lr_callback, checkpoint_callback, tensorboard_callback],
        verbose=1
    )
    model.save_weights(f'Squeeze_net_ratio_trial_{r}.h5')



    val_steps = val_generator1.samples // batch_size
    predictions = model.predict(val_generator1, steps=val_steps)

    true_labels = val_generator1.classes[:val_steps * batch_size]

    num_classes = len(val_generator1.class_indices)
    true_labels_one_hot = tf.keras.utils.to_categorical(true_labels, num_classes)


    top1_metric = tf.keras.metrics.CategoricalAccuracy()
    top5_metric = tf.keras.metrics.TopKCategoricalAccuracy(k=5)
    top1_metric.update_state(true_labels_one_hot, predictions)
    top5_metric.update_state(true_labels_one_hot, predictions)

    print(f"Top-1 Accuracy of squeezenet_{r}", top1_metric.result().numpy())
    print(f"Top-5 Accuracy of squeezenet_{r}", top5_metric.result().numpy())
    model_sq_ratio[r]=model
    sq_ratio_history[r]=training_history
    print('save model', r)
# Out:
# squeeze ratio is 0.125
# Epoch 1/50
# 149/149 [==============================] - ETA: 0s - loss: 2.1553 - accuracy: 0.2246
# Epoch 1: saving model to SqueezeNet_sq_ratio_0.125_epoch_01.h5
# 149/149 [==============================] - 396s 3s/step - loss: 2.1553 - accuracy: 0.2246 - val_loss: 1.9148 - val_accuracy: 0.3058 - lr: 3.0000e-04
# Epoch 2/50
# 149/149 [==============================] - ETA: 0s - loss: 1.7753 - accuracy: 0.3885
# Epoch 2: saving model to SqueezeNet_sq_ratio_0.125_epoch_02.h5
# 149/149 [==============================] - 389s 3s/step - loss: 1.7753 - accuracy: 0.3885 - val_loss: 1.6364 - val_accuracy: 0.4457 - lr: 2.9400e-04
# Epoch 3/50
# 149/149 [==============================] - ETA: 0s - loss: 1.5241 - accuracy: 0.4939
# Epoch 3: saving model to SqueezeNet_sq_ratio_0.125_epoch_03.h5
# 149/149 [==============================] - 384s 3s/step - loss: 1.5241 - accuracy: 0.4939 - val_loss: 1.4586 - val_accuracy: 0.5310 - lr: 2.8800e-04
# Epoch 4/50
# 149/149 [==============================] - ETA: 0s - loss: 1.3751 - accuracy: 0.5451
# Epoch 4: saving model to SqueezeNet_sq_ratio_0.125_epoch_04.h5
# 149/149 [==============================] - 380s 3s/step - loss: 1.3751 - accuracy: 0.5451 - val_loss: 1.3255 - val_accuracy: 0.5799 - lr: 2.8200e-04
# Epoch 5/50
# 149/149 [==============================] - ETA: 0s - loss: 1.2612 - accuracy: 0.5924
# Epoch 5: saving model to SqueezeNet_sq_ratio_0.125_epoch_05.h5
# 149/149 [==============================] - 379s 3s/step - loss: 1.2612 - accuracy: 0.5924 - val_loss: 1.2207 - val_accuracy: 0.6014 - lr: 2.7600e-04
# Epoch 6/50
# 149/149 [==============================] - ETA: 0s - loss: 1.1369 - accuracy: 0.6314
# Epoch 6: saving model to SqueezeNet_sq_ratio_0.125_epoch_06.h5
# 149/149 [==============================] - 380s 3s/step - loss: 1.1369 - accuracy: 0.6314 - val_loss: 1.4047 - val_accuracy: 0.5484 - lr: 2.7000e-04
# Epoch 7/50
# 149/149 [==============================] - ETA: 0s - loss: 1.1076 - accuracy: 0.6394
# Epoch 7: saving model to SqueezeNet_sq_ratio_0.125_epoch_07.h5
# 149/149 [==============================] - 374s 3s/step - loss: 1.1076 - accuracy: 0.6394 - val_loss: 1.0350 - val_accuracy: 0.6749 - lr: 2.6400e-04
# Epoch 8/50
# 149/149 [==============================] - ETA: 0s - loss: 1.0238 - accuracy: 0.6736
# Epoch 8: saving model to SqueezeNet_sq_ratio_0.125_epoch_08.h5
# 149/149 [==============================] - 408s 3s/step - loss: 1.0238 - accuracy: 0.6736 - val_loss: 1.1801 - val_accuracy: 0.6258 - lr: 2.5800e-04
# Epoch 9/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9799 - accuracy: 0.6752
# Epoch 9: saving model to SqueezeNet_sq_ratio_0.125_epoch_09.h5
# 149/149 [==============================] - 414s 3s/step - loss: 0.9799 - accuracy: 0.6752 - val_loss: 0.9628 - val_accuracy: 0.6985 - lr: 2.5200e-04
# Epoch 10/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9147 - accuracy: 0.7105
# Epoch 10: saving model to SqueezeNet_sq_ratio_0.125_epoch_10.h5
# 149/149 [==============================] - 414s 3s/step - loss: 0.9147 - accuracy: 0.7105 - val_loss: 0.9946 - val_accuracy: 0.6916 - lr: 2.4600e-04
# Epoch 11/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.7184
# Epoch 11: saving model to SqueezeNet_sq_ratio_0.125_epoch_11.h5
# 149/149 [==============================] - 419s 3s/step - loss: 0.8824 - accuracy: 0.7184 - val_loss: 0.8898 - val_accuracy: 0.7254 - lr: 2.4000e-04
# Epoch 12/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8201 - accuracy: 0.7324
# Epoch 12: saving model to SqueezeNet_sq_ratio_0.125_epoch_12.h5
# 149/149 [==============================] - 418s 3s/step - loss: 0.8201 - accuracy: 0.7324 - val_loss: 0.9274 - val_accuracy: 0.7252 - lr: 2.3400e-04
# Epoch 13/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7914 - accuracy: 0.7470
# Epoch 13: saving model to SqueezeNet_sq_ratio_0.125_epoch_13.h5
# 149/149 [==============================] - 418s 3s/step - loss: 0.7914 - accuracy: 0.7470 - val_loss: 0.8306 - val_accuracy: 0.7410 - lr: 2.2800e-04
# Epoch 14/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7674 - accuracy: 0.7581
# Epoch 14: saving model to SqueezeNet_sq_ratio_0.125_epoch_14.h5
# 149/149 [==============================] - 420s 3s/step - loss: 0.7674 - accuracy: 0.7581 - val_loss: 0.9606 - val_accuracy: 0.6936 - lr: 2.2200e-04
# Epoch 15/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7420 - accuracy: 0.7629
# Epoch 15: saving model to SqueezeNet_sq_ratio_0.125_epoch_15.h5
# 149/149 [==============================] - 422s 3s/step - loss: 0.7420 - accuracy: 0.7629 - val_loss: 0.9198 - val_accuracy: 0.7198 - lr: 2.1600e-04
# Epoch 16/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7229 - accuracy: 0.7689
# Epoch 16: saving model to SqueezeNet_sq_ratio_0.125_epoch_16.h5
# 149/149 [==============================] - 427s 3s/step - loss: 0.7229 - accuracy: 0.7689 - val_loss: 0.7961 - val_accuracy: 0.7631 - lr: 2.1000e-04
# Epoch 17/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6804 - accuracy: 0.7859
# Epoch 17: saving model to SqueezeNet_sq_ratio_0.125_epoch_17.h5
# 149/149 [==============================] - 434s 3s/step - loss: 0.6804 - accuracy: 0.7859 - val_loss: 0.7573 - val_accuracy: 0.7661 - lr: 2.0400e-04
# Epoch 18/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6441 - accuracy: 0.7977
# Epoch 18: saving model to SqueezeNet_sq_ratio_0.125_epoch_18.h5
# 149/149 [==============================] - 419s 3s/step - loss: 0.6441 - accuracy: 0.7977 - val_loss: 0.8148 - val_accuracy: 0.7431 - lr: 1.9800e-04
# Epoch 19/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.8011
# Epoch 19: saving model to SqueezeNet_sq_ratio_0.125_epoch_19.h5
# 149/149 [==============================] - 422s 3s/step - loss: 0.6257 - accuracy: 0.8011 - val_loss: 0.7641 - val_accuracy: 0.7692 - lr: 1.9200e-04
# Epoch 20/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5931 - accuracy: 0.8106
# Epoch 20: saving model to SqueezeNet_sq_ratio_0.125_epoch_20.h5
# 149/149 [==============================] - 421s 3s/step - loss: 0.5931 - accuracy: 0.8106 - val_loss: 0.8088 - val_accuracy: 0.7608 - lr: 1.8600e-04
# Epoch 21/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.8102
# Epoch 21: saving model to SqueezeNet_sq_ratio_0.125_epoch_21.h5
# 149/149 [==============================] - 422s 3s/step - loss: 0.5955 - accuracy: 0.8102 - val_loss: 0.7471 - val_accuracy: 0.7649 - lr: 1.8000e-04
# Epoch 22/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.8155
# Epoch 22: saving model to SqueezeNet_sq_ratio_0.125_epoch_22.h5
# 149/149 [==============================] - 414s 3s/step - loss: 0.5836 - accuracy: 0.8155 - val_loss: 0.7539 - val_accuracy: 0.7666 - lr: 1.7400e-04
# Epoch 23/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5595 - accuracy: 0.8223
# Epoch 23: saving model to SqueezeNet_sq_ratio_0.125_epoch_23.h5
# 149/149 [==============================] - 420s 3s/step - loss: 0.5595 - accuracy: 0.8223 - val_loss: 0.7128 - val_accuracy: 0.7797 - lr: 1.6800e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5281 - accuracy: 0.8296
# Epoch 24: saving model to SqueezeNet_sq_ratio_0.125_epoch_24.h5
# 149/149 [==============================] - 421s 3s/step - loss: 0.5281 - accuracy: 0.8296 - val_loss: 0.6935 - val_accuracy: 0.7877 - lr: 1.6200e-04
# Epoch 25/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5094 - accuracy: 0.8363
# Epoch 25: saving model to SqueezeNet_sq_ratio_0.125_epoch_25.h5
# 149/149 [==============================] - 420s 3s/step - loss: 0.5094 - accuracy: 0.8363 - val_loss: 0.7507 - val_accuracy: 0.7746 - lr: 1.5600e-04
# Epoch 26/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4951 - accuracy: 0.8410
# Epoch 26: saving model to SqueezeNet_sq_ratio_0.125_epoch_26.h5
# 149/149 [==============================] - 424s 3s/step - loss: 0.4951 - accuracy: 0.8410 - val_loss: 0.7258 - val_accuracy: 0.7836 - lr: 1.5000e-04
# Epoch 27/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4773 - accuracy: 0.8474
# Epoch 27: saving model to SqueezeNet_sq_ratio_0.125_epoch_27.h5
# 149/149 [==============================] - 422s 3s/step - loss: 0.4773 - accuracy: 0.8474 - val_loss: 0.7120 - val_accuracy: 0.7830 - lr: 1.4400e-04
# Epoch 28/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4704 - accuracy: 0.8491
# Epoch 28: saving model to SqueezeNet_sq_ratio_0.125_epoch_28.h5
# 149/149 [==============================] - 425s 3s/step - loss: 0.4704 - accuracy: 0.8491 - val_loss: 0.7234 - val_accuracy: 0.7825 - lr: 1.3800e-04
# Epoch 29/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4304 - accuracy: 0.8658
# Epoch 29: saving model to SqueezeNet_sq_ratio_0.125_epoch_29.h5
# 149/149 [==============================] - 424s 3s/step - loss: 0.4304 - accuracy: 0.8658 - val_loss: 0.7415 - val_accuracy: 0.7700 - lr: 1.3200e-04
# Epoch 30/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4274 - accuracy: 0.8622
# Epoch 30: saving model to SqueezeNet_sq_ratio_0.125_epoch_30.h5
# 149/149 [==============================] - 423s 3s/step - loss: 0.4274 - accuracy: 0.8622 - val_loss: 0.7123 - val_accuracy: 0.7907 - lr: 1.2600e-04
# Epoch 31/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4183 - accuracy: 0.8643
# Epoch 31: saving model to SqueezeNet_sq_ratio_0.125_epoch_31.h5
# 149/149 [==============================] - 427s 3s/step - loss: 0.4183 - accuracy: 0.8643 - val_loss: 0.6944 - val_accuracy: 0.7905 - lr: 1.2000e-04
# Epoch 32/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4051 - accuracy: 0.8709
# Epoch 32: saving model to SqueezeNet_sq_ratio_0.125_epoch_32.h5
# 149/149 [==============================] - 442s 3s/step - loss: 0.4051 - accuracy: 0.8709 - val_loss: 0.6638 - val_accuracy: 0.8043 - lr: 1.1400e-04
# Epoch 33/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.8791
# Epoch 33: saving model to SqueezeNet_sq_ratio_0.125_epoch_33.h5
# 149/149 [==============================] - 428s 3s/step - loss: 0.3787 - accuracy: 0.8791 - val_loss: 0.8049 - val_accuracy: 0.7756 - lr: 1.0800e-04
# Epoch 34/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8826
# Epoch 34: saving model to SqueezeNet_sq_ratio_0.125_epoch_34.h5
# 149/149 [==============================] - 415s 3s/step - loss: 0.3674 - accuracy: 0.8826 - val_loss: 0.6912 - val_accuracy: 0.8002 - lr: 1.0200e-04
# Epoch 35/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3504 - accuracy: 0.8917
# Epoch 35: saving model to SqueezeNet_sq_ratio_0.125_epoch_35.h5
# 149/149 [==============================] - 381s 3s/step - loss: 0.3504 - accuracy: 0.8917 - val_loss: 0.7015 - val_accuracy: 0.7925 - lr: 9.6000e-05
# Epoch 36/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8949
# Epoch 36: saving model to SqueezeNet_sq_ratio_0.125_epoch_36.h5
# 149/149 [==============================] - 389s 3s/step - loss: 0.3328 - accuracy: 0.8949 - val_loss: 0.6903 - val_accuracy: 0.7984 - lr: 9.0000e-05
# Epoch 37/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3196 - accuracy: 0.8996
# Epoch 37: saving model to SqueezeNet_sq_ratio_0.125_epoch_37.h5
# 149/149 [==============================] - 379s 3s/step - loss: 0.3196 - accuracy: 0.8996 - val_loss: 0.7594 - val_accuracy: 0.7889 - lr: 8.4000e-05
# Epoch 38/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3018 - accuracy: 0.9055
# Epoch 38: saving model to SqueezeNet_sq_ratio_0.125_epoch_38.h5
# 149/149 [==============================] - 375s 3s/step - loss: 0.3018 - accuracy: 0.9055 - val_loss: 0.7149 - val_accuracy: 0.8056 - lr: 7.8000e-05
# Epoch 39/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.9135
# Epoch 39: saving model to SqueezeNet_sq_ratio_0.125_epoch_39.h5
# 149/149 [==============================] - 397s 3s/step - loss: 0.2796 - accuracy: 0.9135 - val_loss: 0.7537 - val_accuracy: 0.7877 - lr: 7.2000e-05
# Epoch 40/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.9104
# Epoch 40: saving model to SqueezeNet_sq_ratio_0.125_epoch_40.h5
# 149/149 [==============================] - 406s 3s/step - loss: 0.2896 - accuracy: 0.9104 - val_loss: 0.7140 - val_accuracy: 0.8017 - lr: 6.6000e-05
# Epoch 41/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9166
# Epoch 41: saving model to SqueezeNet_sq_ratio_0.125_epoch_41.h5
# 149/149 [==============================] - 412s 3s/step - loss: 0.2677 - accuracy: 0.9166 - val_loss: 0.7036 - val_accuracy: 0.8043 - lr: 6.0000e-05
# Epoch 42/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9207
# Epoch 42: saving model to SqueezeNet_sq_ratio_0.125_epoch_42.h5
# 149/149 [==============================] - 407s 3s/step - loss: 0.2535 - accuracy: 0.9207 - val_loss: 0.6989 - val_accuracy: 0.8105 - lr: 5.4000e-05
# Epoch 43/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.9248
# Epoch 43: saving model to SqueezeNet_sq_ratio_0.125_epoch_43.h5
# 149/149 [==============================] - 404s 3s/step - loss: 0.2440 - accuracy: 0.9248 - val_loss: 0.7322 - val_accuracy: 0.8015 - lr: 4.8000e-05
# Epoch 44/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.9284
# Epoch 44: saving model to SqueezeNet_sq_ratio_0.125_epoch_44.h5
# 149/149 [==============================] - 419s 3s/step - loss: 0.2318 - accuracy: 0.9284 - val_loss: 0.7299 - val_accuracy: 0.8074 - lr: 4.2000e-05
# Epoch 45/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9335
# Epoch 45: saving model to SqueezeNet_sq_ratio_0.125_epoch_45.h5
# 149/149 [==============================] - 414s 3s/step - loss: 0.2188 - accuracy: 0.9335 - val_loss: 0.7210 - val_accuracy: 0.8128 - lr: 3.6000e-05
# Epoch 46/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9355
# Epoch 46: saving model to SqueezeNet_sq_ratio_0.125_epoch_46.h5
# 149/149 [==============================] - 415s 3s/step - loss: 0.2112 - accuracy: 0.9355 - val_loss: 0.7325 - val_accuracy: 0.8089 - lr: 3.0000e-05
# Epoch 47/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9383
# Epoch 47: saving model to SqueezeNet_sq_ratio_0.125_epoch_47.h5
# 149/149 [==============================] - 411s 3s/step - loss: 0.1995 - accuracy: 0.9383 - val_loss: 0.7403 - val_accuracy: 0.8097 - lr: 2.4000e-05
# Epoch 48/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9432
# Epoch 48: saving model to SqueezeNet_sq_ratio_0.125_epoch_48.h5
# 149/149 [==============================] - 416s 3s/step - loss: 0.1913 - accuracy: 0.9432 - val_loss: 0.7351 - val_accuracy: 0.8074 - lr: 1.8000e-05
# Epoch 49/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9461
# Epoch 49: saving model to SqueezeNet_sq_ratio_0.125_epoch_49.h5
# 149/149 [==============================] - 413s 3s/step - loss: 0.1828 - accuracy: 0.9461 - val_loss: 0.7240 - val_accuracy: 0.8135 - lr: 1.2000e-05
# Epoch 50/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9480
# Epoch 50: saving model to SqueezeNet_sq_ratio_0.125_epoch_50.h5
# 149/149 [==============================] - 420s 3s/step - loss: 0.1753 - accuracy: 0.9480 - val_loss: 0.7377 - val_accuracy: 0.8120 - lr: 6.0000e-06
# 61/61 [==============================] - 43s 704ms/step
# Top-1 Accuracy of squeezenet_0.125 0.8122439
# Top-5 Accuracy of squeezenet_0.125 0.9836066
# save model 0.125
# squeeze ratio is 0.25
# Epoch 1/50
# 149/149 [==============================] - ETA: 0s - loss: 2.4579 - accuracy: 0.1357
# Epoch 1: saving model to SqueezeNet_sq_ratio_0.25_epoch_01.h5
# 149/149 [==============================] - 647s 4s/step - loss: 2.4579 - accuracy: 0.1357 - val_loss: 2.2443 - val_accuracy: 0.1883 - lr: 3.0000e-04
# Epoch 2/50
# 149/149 [==============================] - ETA: 0s - loss: 2.1306 - accuracy: 0.2418
# Epoch 2: saving model to SqueezeNet_sq_ratio_0.25_epoch_02.h5
# 149/149 [==============================] - 597s 4s/step - loss: 2.1306 - accuracy: 0.2418 - val_loss: 2.0499 - val_accuracy: 0.3094 - lr: 2.9400e-04
# Epoch 3/50
# 149/149 [==============================] - ETA: 0s - loss: 1.8726 - accuracy: 0.3650
# Epoch 3: saving model to SqueezeNet_sq_ratio_0.25_epoch_03.h5
# 149/149 [==============================] - 585s 4s/step - loss: 1.8726 - accuracy: 0.3650 - val_loss: 1.6011 - val_accuracy: 0.4867 - lr: 2.8800e-04
# Epoch 4/50
# 149/149 [==============================] - ETA: 0s - loss: 1.5867 - accuracy: 0.4706
# Epoch 4: saving model to SqueezeNet_sq_ratio_0.25_epoch_04.h5
# 149/149 [==============================] - 585s 4s/step - loss: 1.5867 - accuracy: 0.4706 - val_loss: 1.6596 - val_accuracy: 0.4731 - lr: 2.8200e-04
# Epoch 5/50
# 149/149 [==============================] - ETA: 0s - loss: 1.3663 - accuracy: 0.5505
# Epoch 5: saving model to SqueezeNet_sq_ratio_0.25_epoch_05.h5
# 149/149 [==============================] - 584s 4s/step - loss: 1.3663 - accuracy: 0.5505 - val_loss: 1.3001 - val_accuracy: 0.5961 - lr: 2.7600e-04
# Epoch 6/50
# 149/149 [==============================] - ETA: 0s - loss: 1.2340 - accuracy: 0.5981
# Epoch 6: saving model to SqueezeNet_sq_ratio_0.25_epoch_06.h5
# 149/149 [==============================] - 578s 4s/step - loss: 1.2340 - accuracy: 0.5981 - val_loss: 1.2004 - val_accuracy: 0.6148 - lr: 2.7000e-04
# Epoch 7/50
# 149/149 [==============================] - ETA: 0s - loss: 1.1164 - accuracy: 0.6422
# Epoch 7: saving model to SqueezeNet_sq_ratio_0.25_epoch_07.h5
# 149/149 [==============================] - 590s 4s/step - loss: 1.1164 - accuracy: 0.6422 - val_loss: 1.2319 - val_accuracy: 0.5950 - lr: 2.6400e-04
# Epoch 8/50
# 149/149 [==============================] - ETA: 0s - loss: 1.0436 - accuracy: 0.6631
# Epoch 8: saving model to SqueezeNet_sq_ratio_0.25_epoch_08.h5
# 149/149 [==============================] - 593s 4s/step - loss: 1.0436 - accuracy: 0.6631 - val_loss: 1.2055 - val_accuracy: 0.6055 - lr: 2.5800e-04
# Epoch 9/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9576 - accuracy: 0.6915
# Epoch 9: saving model to SqueezeNet_sq_ratio_0.25_epoch_09.h5
# 149/149 [==============================] - 586s 4s/step - loss: 0.9576 - accuracy: 0.6915 - val_loss: 1.0418 - val_accuracy: 0.6770 - lr: 2.5200e-04
# Epoch 10/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8932 - accuracy: 0.7161
# Epoch 10: saving model to SqueezeNet_sq_ratio_0.25_epoch_10.h5
# 149/149 [==============================] - 584s 4s/step - loss: 0.8932 - accuracy: 0.7161 - val_loss: 0.9076 - val_accuracy: 0.7134 - lr: 2.4600e-04
# Epoch 11/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8249 - accuracy: 0.7354
# Epoch 11: saving model to SqueezeNet_sq_ratio_0.25_epoch_11.h5
# 149/149 [==============================] - 586s 4s/step - loss: 0.8249 - accuracy: 0.7354 - val_loss: 0.9036 - val_accuracy: 0.7164 - lr: 2.4000e-04
# Epoch 12/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8024 - accuracy: 0.7442
# Epoch 12: saving model to SqueezeNet_sq_ratio_0.25_epoch_12.h5
# 149/149 [==============================] - 585s 4s/step - loss: 0.8024 - accuracy: 0.7442 - val_loss: 0.8641 - val_accuracy: 0.7318 - lr: 2.3400e-04
# Epoch 13/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7583 - accuracy: 0.7585
# Epoch 13: saving model to SqueezeNet_sq_ratio_0.25_epoch_13.h5
# 149/149 [==============================] - 593s 4s/step - loss: 0.7583 - accuracy: 0.7585 - val_loss: 0.7856 - val_accuracy: 0.7531 - lr: 2.2800e-04
# Epoch 14/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7211 - accuracy: 0.7705
# Epoch 14: saving model to SqueezeNet_sq_ratio_0.25_epoch_14.h5
# 149/149 [==============================] - 582s 4s/step - loss: 0.7211 - accuracy: 0.7705 - val_loss: 0.7903 - val_accuracy: 0.7620 - lr: 2.2200e-04
# Epoch 15/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6722 - accuracy: 0.7882
# Epoch 15: saving model to SqueezeNet_sq_ratio_0.25_epoch_15.h5
# 149/149 [==============================] - 576s 4s/step - loss: 0.6722 - accuracy: 0.7882 - val_loss: 0.7999 - val_accuracy: 0.7482 - lr: 2.1600e-04
# Epoch 16/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6562 - accuracy: 0.7890
# Epoch 16: saving model to SqueezeNet_sq_ratio_0.25_epoch_16.h5
# 149/149 [==============================] - 544s 4s/step - loss: 0.6562 - accuracy: 0.7890 - val_loss: 0.7920 - val_accuracy: 0.7677 - lr: 2.1000e-04
# Epoch 17/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6116 - accuracy: 0.8019
# Epoch 17: saving model to SqueezeNet_sq_ratio_0.25_epoch_17.h5
# 149/149 [==============================] - 535s 4s/step - loss: 0.6116 - accuracy: 0.8019 - val_loss: 0.7905 - val_accuracy: 0.7669 - lr: 2.0400e-04
# Epoch 18/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5827 - accuracy: 0.8122
# Epoch 18: saving model to SqueezeNet_sq_ratio_0.25_epoch_18.h5
# 149/149 [==============================] - 669s 4s/step - loss: 0.5827 - accuracy: 0.8122 - val_loss: 0.8252 - val_accuracy: 0.7531 - lr: 1.9800e-04
# Epoch 19/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5491 - accuracy: 0.8240
# Epoch 19: saving model to SqueezeNet_sq_ratio_0.25_epoch_19.h5
# 149/149 [==============================] - 553s 4s/step - loss: 0.5491 - accuracy: 0.8240 - val_loss: 0.7433 - val_accuracy: 0.7738 - lr: 1.9200e-04
# Epoch 20/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5356 - accuracy: 0.8254
# Epoch 20: saving model to SqueezeNet_sq_ratio_0.25_epoch_20.h5
# 149/149 [==============================] - 541s 4s/step - loss: 0.5356 - accuracy: 0.8254 - val_loss: 0.7058 - val_accuracy: 0.7884 - lr: 1.8600e-04
# Epoch 21/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.8379
# Epoch 21: saving model to SqueezeNet_sq_ratio_0.25_epoch_21.h5
# 149/149 [==============================] - 546s 4s/step - loss: 0.4958 - accuracy: 0.8379 - val_loss: 0.8130 - val_accuracy: 0.7677 - lr: 1.8000e-04
# Epoch 22/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5060 - accuracy: 0.8346
# Epoch 22: saving model to SqueezeNet_sq_ratio_0.25_epoch_22.h5
# 149/149 [==============================] - 586s 4s/step - loss: 0.5060 - accuracy: 0.8346 - val_loss: 0.7061 - val_accuracy: 0.7897 - lr: 1.7400e-04
# Epoch 23/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4628 - accuracy: 0.8482
# Epoch 23: saving model to SqueezeNet_sq_ratio_0.25_epoch_23.h5
# 149/149 [==============================] - 663s 4s/step - loss: 0.4628 - accuracy: 0.8482 - val_loss: 0.7613 - val_accuracy: 0.7779 - lr: 1.6800e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4451 - accuracy: 0.8559
# Epoch 24: saving model to SqueezeNet_sq_ratio_0.25_epoch_24.h5
# 149/149 [==============================] - 920s 6s/step - loss: 0.4451 - accuracy: 0.8559 - val_loss: 0.7392 - val_accuracy: 0.7882 - lr: 1.6200e-04
# Epoch 25/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4273 - accuracy: 0.8646
# Epoch 25: saving model to SqueezeNet_sq_ratio_0.25_epoch_25.h5
# 149/149 [==============================] - 716s 5s/step - loss: 0.4273 - accuracy: 0.8646 - val_loss: 0.6752 - val_accuracy: 0.7969 - lr: 1.5600e-04
# Epoch 26/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.8774
# Epoch 26: saving model to SqueezeNet_sq_ratio_0.25_epoch_26.h5
# 149/149 [==============================] - 715s 5s/step - loss: 0.3768 - accuracy: 0.8774 - val_loss: 0.6845 - val_accuracy: 0.8061 - lr: 1.5000e-04
# Epoch 27/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8826
# Epoch 27: saving model to SqueezeNet_sq_ratio_0.25_epoch_27.h5
# 149/149 [==============================] - 818s 5s/step - loss: 0.3722 - accuracy: 0.8826 - val_loss: 0.7241 - val_accuracy: 0.7900 - lr: 1.4400e-04
# Epoch 28/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3527 - accuracy: 0.8849
# Epoch 28: saving model to SqueezeNet_sq_ratio_0.25_epoch_28.h5
# 149/149 [==============================] - 717s 5s/step - loss: 0.3527 - accuracy: 0.8849 - val_loss: 0.7162 - val_accuracy: 0.7961 - lr: 1.3800e-04
# Epoch 29/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8936
# Epoch 29: saving model to SqueezeNet_sq_ratio_0.25_epoch_29.h5
# 149/149 [==============================] - 844s 6s/step - loss: 0.3222 - accuracy: 0.8936 - val_loss: 0.6909 - val_accuracy: 0.8030 - lr: 1.3200e-04
# Epoch 30/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3201 - accuracy: 0.8981
# Epoch 30: saving model to SqueezeNet_sq_ratio_0.25_epoch_30.h5
# 149/149 [==============================] - 780s 5s/step - loss: 0.3201 - accuracy: 0.8981 - val_loss: 0.7560 - val_accuracy: 0.7843 - lr: 1.2600e-04
# Epoch 31/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.9077
# Epoch 31: saving model to SqueezeNet_sq_ratio_0.25_epoch_31.h5
# 149/149 [==============================] - 724s 5s/step - loss: 0.2864 - accuracy: 0.9077 - val_loss: 0.7830 - val_accuracy: 0.7882 - lr: 1.2000e-04
# Epoch 32/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.9200
# Epoch 32: saving model to SqueezeNet_sq_ratio_0.25_epoch_32.h5
# 149/149 [==============================] - 1269s 8s/step - loss: 0.2527 - accuracy: 0.9200 - val_loss: 0.7419 - val_accuracy: 0.8023 - lr: 1.1400e-04
# Epoch 33/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2421 - accuracy: 0.9220
# Epoch 33: saving model to SqueezeNet_sq_ratio_0.25_epoch_33.h5
# 149/149 [==============================] - 2067s 14s/step - loss: 0.2421 - accuracy: 0.9220 - val_loss: 0.7813 - val_accuracy: 0.7877 - lr: 1.0800e-04
# Epoch 34/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.9226
# Epoch 34: saving model to SqueezeNet_sq_ratio_0.25_epoch_34.h5
# 149/149 [==============================] - 552s 4s/step - loss: 0.2440 - accuracy: 0.9226 - val_loss: 0.7892 - val_accuracy: 0.8038 - lr: 1.0200e-04
# Epoch 35/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2142 - accuracy: 0.9339
# Epoch 35: saving model to SqueezeNet_sq_ratio_0.25_epoch_35.h5
# 149/149 [==============================] - 540s 4s/step - loss: 0.2142 - accuracy: 0.9339 - val_loss: 0.7393 - val_accuracy: 0.8145 - lr: 9.6000e-05
# Epoch 36/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9398
# Epoch 36: saving model to SqueezeNet_sq_ratio_0.25_epoch_36.h5
# 149/149 [==============================] - 526s 4s/step - loss: 0.1872 - accuracy: 0.9398 - val_loss: 0.8156 - val_accuracy: 0.7928 - lr: 9.0000e-05
# Epoch 37/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9395
# Epoch 37: saving model to SqueezeNet_sq_ratio_0.25_epoch_37.h5
# 149/149 [==============================] - 560s 4s/step - loss: 0.1898 - accuracy: 0.9395 - val_loss: 0.7591 - val_accuracy: 0.8035 - lr: 8.4000e-05
# Epoch 38/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.9450
# Epoch 38: saving model to SqueezeNet_sq_ratio_0.25_epoch_38.h5
# 149/149 [==============================] - 596s 4s/step - loss: 0.1654 - accuracy: 0.9450 - val_loss: 0.7947 - val_accuracy: 0.8092 - lr: 7.8000e-05
# Epoch 39/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9520
# Epoch 39: saving model to SqueezeNet_sq_ratio_0.25_epoch_39.h5
# 149/149 [==============================] - 588s 4s/step - loss: 0.1463 - accuracy: 0.9520 - val_loss: 0.8654 - val_accuracy: 0.7971 - lr: 7.2000e-05
# Epoch 40/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9588
# Epoch 40: saving model to SqueezeNet_sq_ratio_0.25_epoch_40.h5
# 149/149 [==============================] - 598s 4s/step - loss: 0.1289 - accuracy: 0.9588 - val_loss: 0.8762 - val_accuracy: 0.8058 - lr: 6.6000e-05
# Epoch 41/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9649
# Epoch 41: saving model to SqueezeNet_sq_ratio_0.25_epoch_41.h5
# 149/149 [==============================] - 587s 4s/step - loss: 0.1133 - accuracy: 0.9649 - val_loss: 0.8559 - val_accuracy: 0.8125 - lr: 6.0000e-05
# Epoch 42/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9680
# Epoch 42: saving model to SqueezeNet_sq_ratio_0.25_epoch_42.h5
# 149/149 [==============================] - 592s 4s/step - loss: 0.1044 - accuracy: 0.9680 - val_loss: 0.8719 - val_accuracy: 0.8002 - lr: 5.4000e-05
# Epoch 43/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9736
# Epoch 43: saving model to SqueezeNet_sq_ratio_0.25_epoch_43.h5
# 149/149 [==============================] - 601s 4s/step - loss: 0.0890 - accuracy: 0.9736 - val_loss: 0.8843 - val_accuracy: 0.8163 - lr: 4.8000e-05
# Epoch 44/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9759
# Epoch 44: saving model to SqueezeNet_sq_ratio_0.25_epoch_44.h5
# 149/149 [==============================] - 610s 4s/step - loss: 0.0747 - accuracy: 0.9759 - val_loss: 0.8927 - val_accuracy: 0.8107 - lr: 4.2000e-05
# Epoch 45/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9791
# Epoch 45: saving model to SqueezeNet_sq_ratio_0.25_epoch_45.h5
# 149/149 [==============================] - 610s 4s/step - loss: 0.0679 - accuracy: 0.9791 - val_loss: 0.9092 - val_accuracy: 0.8145 - lr: 3.6000e-05
# Epoch 46/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9834
# Epoch 46: saving model to SqueezeNet_sq_ratio_0.25_epoch_46.h5
# 149/149 [==============================] - 609s 4s/step - loss: 0.0604 - accuracy: 0.9834 - val_loss: 0.9566 - val_accuracy: 0.8125 - lr: 3.0000e-05
# Epoch 47/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9833
# Epoch 47: saving model to SqueezeNet_sq_ratio_0.25_epoch_47.h5
# 149/149 [==============================] - 609s 4s/step - loss: 0.0544 - accuracy: 0.9833 - val_loss: 0.9554 - val_accuracy: 0.8120 - lr: 2.4000e-05
# Epoch 48/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9892
# Epoch 48: saving model to SqueezeNet_sq_ratio_0.25_epoch_48.h5
# 149/149 [==============================] - 605s 4s/step - loss: 0.0448 - accuracy: 0.9892 - val_loss: 0.9485 - val_accuracy: 0.8197 - lr: 1.8000e-05
# Epoch 49/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9896
# Epoch 49: saving model to SqueezeNet_sq_ratio_0.25_epoch_49.h5
# 149/149 [==============================] - 606s 4s/step - loss: 0.0414 - accuracy: 0.9896 - val_loss: 0.9732 - val_accuracy: 0.8153 - lr: 1.2000e-05
# Epoch 50/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9922
# Epoch 50: saving model to SqueezeNet_sq_ratio_0.25_epoch_50.h5
# 149/149 [==============================] - 612s 4s/step - loss: 0.0358 - accuracy: 0.9922 - val_loss: 0.9798 - val_accuracy: 0.8169 - lr: 6.0000e-06
# 61/61 [==============================] - 60s 976ms/step
# Top-1 Accuracy of squeezenet_0.25 0.81813526
# Top-5 Accuracy of squeezenet_0.25 0.98181355
# save model 0.25
# squeeze ratio is 0.5
# Epoch 1/50
# 149/149 [==============================] - ETA: 0s - loss: 2.5133 - accuracy: 0.1419
# Epoch 1: saving model to SqueezeNet_sq_ratio_0.5_epoch_01.h5
# 149/149 [==============================] - 969s 6s/step - loss: 2.5133 - accuracy: 0.1419 - val_loss: 2.2154 - val_accuracy: 0.1814 - lr: 3.0000e-04
# Epoch 2/50
# 149/149 [==============================] - ETA: 0s - loss: 2.1196 - accuracy: 0.2612
# Epoch 2: saving model to SqueezeNet_sq_ratio_0.5_epoch_02.h5
# 149/149 [==============================] - 960s 6s/step - loss: 2.1196 - accuracy: 0.2612 - val_loss: 2.1519 - val_accuracy: 0.2195 - lr: 2.9400e-04
# Epoch 3/50
# 149/149 [==============================] - ETA: 0s - loss: 2.0408 - accuracy: 0.3016
# Epoch 3: saving model to SqueezeNet_sq_ratio_0.5_epoch_03.h5
# 149/149 [==============================] - 963s 6s/step - loss: 2.0408 - accuracy: 0.3016 - val_loss: 1.9827 - val_accuracy: 0.3425 - lr: 2.8800e-04
# Epoch 4/50
# 149/149 [==============================] - ETA: 0s - loss: 1.8157 - accuracy: 0.3983
# Epoch 4: saving model to SqueezeNet_sq_ratio_0.5_epoch_04.h5
# 149/149 [==============================] - 973s 7s/step - loss: 1.8157 - accuracy: 0.3983 - val_loss: 1.7065 - val_accuracy: 0.4495 - lr: 2.8200e-04
# Epoch 5/50
# 149/149 [==============================] - ETA: 0s - loss: 1.6950 - accuracy: 0.4491
# Epoch 5: saving model to SqueezeNet_sq_ratio_0.5_epoch_05.h5
# 149/149 [==============================] - 1012s 7s/step - loss: 1.6950 - accuracy: 0.4491 - val_loss: 1.5371 - val_accuracy: 0.5113 - lr: 2.7600e-04
# Epoch 6/50
# 149/149 [==============================] - ETA: 0s - loss: 1.5221 - accuracy: 0.5120
# Epoch 6: saving model to SqueezeNet_sq_ratio_0.5_epoch_06.h5
# 149/149 [==============================] - 973s 7s/step - loss: 1.5221 - accuracy: 0.5120 - val_loss: 1.4605 - val_accuracy: 0.4877 - lr: 2.7000e-04
# Epoch 7/50
# 149/149 [==============================] - ETA: 0s - loss: 1.2692 - accuracy: 0.5876
# Epoch 7: saving model to SqueezeNet_sq_ratio_0.5_epoch_07.h5
# 149/149 [==============================] - 979s 7s/step - loss: 1.2692 - accuracy: 0.5876 - val_loss: 1.1690 - val_accuracy: 0.6270 - lr: 2.6400e-04
# Epoch 8/50
# 149/149 [==============================] - ETA: 0s - loss: 1.1583 - accuracy: 0.6256
# Epoch 8: saving model to SqueezeNet_sq_ratio_0.5_epoch_08.h5
# 149/149 [==============================] - 887s 6s/step - loss: 1.1583 - accuracy: 0.6256 - val_loss: 1.0523 - val_accuracy: 0.6685 - lr: 2.5800e-04
# Epoch 9/50
# 149/149 [==============================] - ETA: 0s - loss: 1.0408 - accuracy: 0.6693
# Epoch 9: saving model to SqueezeNet_sq_ratio_0.5_epoch_09.h5
# 149/149 [==============================] - 1102s 7s/step - loss: 1.0408 - accuracy: 0.6693 - val_loss: 0.9985 - val_accuracy: 0.6885 - lr: 2.5200e-04
# Epoch 10/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9687 - accuracy: 0.6906
# Epoch 10: saving model to SqueezeNet_sq_ratio_0.5_epoch_10.h5
# 149/149 [==============================] - 1069s 7s/step - loss: 0.9687 - accuracy: 0.6906 - val_loss: 0.9253 - val_accuracy: 0.7126 - lr: 2.4600e-04
# Epoch 11/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8530 - accuracy: 0.7303
# Epoch 11: saving model to SqueezeNet_sq_ratio_0.5_epoch_11.h5
# 149/149 [==============================] - 1109s 7s/step - loss: 0.8530 - accuracy: 0.7303 - val_loss: 0.8945 - val_accuracy: 0.7252 - lr: 2.4000e-04
# Epoch 12/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8029 - accuracy: 0.7442
# Epoch 12: saving model to SqueezeNet_sq_ratio_0.5_epoch_12.h5
# 149/149 [==============================] - 1188s 8s/step - loss: 0.8029 - accuracy: 0.7442 - val_loss: 0.8552 - val_accuracy: 0.7328 - lr: 2.3400e-04
# Epoch 13/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7375 - accuracy: 0.7685
# Epoch 13: saving model to SqueezeNet_sq_ratio_0.5_epoch_13.h5
# 149/149 [==============================] - 1355s 9s/step - loss: 0.7375 - accuracy: 0.7685 - val_loss: 0.8316 - val_accuracy: 0.7321 - lr: 2.2800e-04
# Epoch 14/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7006 - accuracy: 0.7781
# Epoch 14: saving model to SqueezeNet_sq_ratio_0.5_epoch_14.h5
# 149/149 [==============================] - 1596s 11s/step - loss: 0.7006 - accuracy: 0.7781 - val_loss: 0.7484 - val_accuracy: 0.7700 - lr: 2.2200e-04
# Epoch 15/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6504 - accuracy: 0.7933
# Epoch 15: saving model to SqueezeNet_sq_ratio_0.5_epoch_15.h5
# 149/149 [==============================] - 889s 6s/step - loss: 0.6504 - accuracy: 0.7933 - val_loss: 0.8727 - val_accuracy: 0.7449 - lr: 2.1600e-04
# Epoch 16/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6137 - accuracy: 0.8045
# Epoch 16: saving model to SqueezeNet_sq_ratio_0.5_epoch_16.h5
# 149/149 [==============================] - 848s 6s/step - loss: 0.6137 - accuracy: 0.8045 - val_loss: 0.7367 - val_accuracy: 0.7741 - lr: 2.1000e-04
# Epoch 17/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5798 - accuracy: 0.8142
# Epoch 17: saving model to SqueezeNet_sq_ratio_0.5_epoch_17.h5
# 149/149 [==============================] - 874s 6s/step - loss: 0.5798 - accuracy: 0.8142 - val_loss: 0.7913 - val_accuracy: 0.7492 - lr: 2.0400e-04
# Epoch 18/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5481 - accuracy: 0.8238
# Epoch 18: saving model to SqueezeNet_sq_ratio_0.5_epoch_18.h5
# 149/149 [==============================] - 903s 6s/step - loss: 0.5481 - accuracy: 0.8238 - val_loss: 0.7957 - val_accuracy: 0.7474 - lr: 1.9800e-04
# Epoch 19/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5081 - accuracy: 0.8380
# Epoch 19: saving model to SqueezeNet_sq_ratio_0.5_epoch_19.h5
# 149/149 [==============================] - 903s 6s/step - loss: 0.5081 - accuracy: 0.8380 - val_loss: 0.7163 - val_accuracy: 0.7843 - lr: 1.9200e-04
# Epoch 20/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8533
# Epoch 20: saving model to SqueezeNet_sq_ratio_0.5_epoch_20.h5
# 149/149 [==============================] - 864s 6s/step - loss: 0.4654 - accuracy: 0.8533 - val_loss: 0.6578 - val_accuracy: 0.7956 - lr: 1.8600e-04
# Epoch 21/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.8521
# Epoch 21: saving model to SqueezeNet_sq_ratio_0.5_epoch_21.h5
# 149/149 [==============================] - 867s 6s/step - loss: 0.4585 - accuracy: 0.8521 - val_loss: 0.6360 - val_accuracy: 0.8076 - lr: 1.8000e-04
# Epoch 22/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4157 - accuracy: 0.8672
# Epoch 22: saving model to SqueezeNet_sq_ratio_0.5_epoch_22.h5
# 149/149 [==============================] - 949s 6s/step - loss: 0.4157 - accuracy: 0.8672 - val_loss: 0.7548 - val_accuracy: 0.7805 - lr: 1.7400e-04
# Epoch 23/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.8692
# Epoch 23: saving model to SqueezeNet_sq_ratio_0.5_epoch_23.h5
# 149/149 [==============================] - 919s 6s/step - loss: 0.4060 - accuracy: 0.8692 - val_loss: 0.7000 - val_accuracy: 0.7912 - lr: 1.6800e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.8746
# Epoch 24: saving model to SqueezeNet_sq_ratio_0.5_epoch_24.h5
# 149/149 [==============================] - 869s 6s/step - loss: 0.3942 - accuracy: 0.8746 - val_loss: 0.6376 - val_accuracy: 0.8112 - lr: 1.6200e-04
# Epoch 25/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8926
# Epoch 25: saving model to SqueezeNet_sq_ratio_0.5_epoch_25.h5
# 149/149 [==============================] - 942s 6s/step - loss: 0.3366 - accuracy: 0.8926 - val_loss: 0.6812 - val_accuracy: 0.8040 - lr: 1.5600e-04
# Epoch 26/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3143 - accuracy: 0.8983
# Epoch 26: saving model to SqueezeNet_sq_ratio_0.5_epoch_26.h5
# 149/149 [==============================] - 977s 7s/step - loss: 0.3143 - accuracy: 0.8983 - val_loss: 0.6526 - val_accuracy: 0.8156 - lr: 1.5000e-04
# Epoch 27/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.9089
# Epoch 27: saving model to SqueezeNet_sq_ratio_0.5_epoch_27.h5
# 149/149 [==============================] - 925s 6s/step - loss: 0.2872 - accuracy: 0.9089 - val_loss: 0.7720 - val_accuracy: 0.7946 - lr: 1.4400e-04
# Epoch 28/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9117
# Epoch 28: saving model to SqueezeNet_sq_ratio_0.5_epoch_28.h5
# 149/149 [==============================] - 890s 6s/step - loss: 0.2745 - accuracy: 0.9117 - val_loss: 0.6564 - val_accuracy: 0.8158 - lr: 1.3800e-04
# Epoch 29/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9217
# Epoch 29: saving model to SqueezeNet_sq_ratio_0.5_epoch_29.h5
# 149/149 [==============================] - 920s 6s/step - loss: 0.2448 - accuracy: 0.9217 - val_loss: 0.6715 - val_accuracy: 0.8133 - lr: 1.3200e-04
# Epoch 30/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9306
# Epoch 30: saving model to SqueezeNet_sq_ratio_0.5_epoch_30.h5
# 149/149 [==============================] - 965s 6s/step - loss: 0.2106 - accuracy: 0.9306 - val_loss: 0.6860 - val_accuracy: 0.8261 - lr: 1.2600e-04
# Epoch 31/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9272
# Epoch 31: saving model to SqueezeNet_sq_ratio_0.5_epoch_31.h5
# 149/149 [==============================] - 947s 6s/step - loss: 0.2203 - accuracy: 0.9272 - val_loss: 0.7285 - val_accuracy: 0.8161 - lr: 1.2000e-04
# Epoch 32/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9474
# Epoch 32: saving model to SqueezeNet_sq_ratio_0.5_epoch_32.h5
# 149/149 [==============================] - 908s 6s/step - loss: 0.1701 - accuracy: 0.9474 - val_loss: 0.7826 - val_accuracy: 0.8094 - lr: 1.1400e-04
# Epoch 33/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1577 - accuracy: 0.9505
# Epoch 33: saving model to SqueezeNet_sq_ratio_0.5_epoch_33.h5
# 149/149 [==============================] - 928s 6s/step - loss: 0.1577 - accuracy: 0.9505 - val_loss: 0.7808 - val_accuracy: 0.8081 - lr: 1.0800e-04
# Epoch 34/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1481 - accuracy: 0.9517
# Epoch 34: saving model to SqueezeNet_sq_ratio_0.5_epoch_34.h5
# 149/149 [==============================] - 994s 7s/step - loss: 0.1481 - accuracy: 0.9517 - val_loss: 0.7226 - val_accuracy: 0.8256 - lr: 1.0200e-04
# Epoch 35/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9623
# Epoch 35: saving model to SqueezeNet_sq_ratio_0.5_epoch_35.h5
# 149/149 [==============================] - 905s 6s/step - loss: 0.1208 - accuracy: 0.9623 - val_loss: 0.7338 - val_accuracy: 0.8302 - lr: 9.6000e-05
# Epoch 36/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9595
# Epoch 36: saving model to SqueezeNet_sq_ratio_0.5_epoch_36.h5
# 149/149 [==============================] - 858s 6s/step - loss: 0.1306 - accuracy: 0.9595 - val_loss: 0.7319 - val_accuracy: 0.8230 - lr: 9.0000e-05
# Epoch 37/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9680
# Epoch 37: saving model to SqueezeNet_sq_ratio_0.5_epoch_37.h5
# 149/149 [==============================] - 916s 6s/step - loss: 0.1019 - accuracy: 0.9680 - val_loss: 0.7358 - val_accuracy: 0.8184 - lr: 8.4000e-05
# Epoch 38/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9775
# Epoch 38: saving model to SqueezeNet_sq_ratio_0.5_epoch_38.h5
# 149/149 [==============================] - 925s 6s/step - loss: 0.0733 - accuracy: 0.9775 - val_loss: 0.8491 - val_accuracy: 0.8210 - lr: 7.8000e-05
# Epoch 39/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9714
# Epoch 39: saving model to SqueezeNet_sq_ratio_0.5_epoch_39.h5
# 149/149 [==============================] - 932s 6s/step - loss: 0.0868 - accuracy: 0.9714 - val_loss: 0.8156 - val_accuracy: 0.8235 - lr: 7.2000e-05
# Epoch 40/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9843
# Epoch 40: saving model to SqueezeNet_sq_ratio_0.5_epoch_40.h5
# 149/149 [==============================] - 932s 6s/step - loss: 0.0559 - accuracy: 0.9843 - val_loss: 0.9487 - val_accuracy: 0.8181 - lr: 6.6000e-05
# Epoch 41/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9843
# Epoch 41: saving model to SqueezeNet_sq_ratio_0.5_epoch_41.h5
# 149/149 [==============================] - 937s 6s/step - loss: 0.0512 - accuracy: 0.9843 - val_loss: 0.8545 - val_accuracy: 0.8261 - lr: 6.0000e-05
# Epoch 42/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9892
# Epoch 42: saving model to SqueezeNet_sq_ratio_0.5_epoch_42.h5
# 149/149 [==============================] - 936s 6s/step - loss: 0.0412 - accuracy: 0.9892 - val_loss: 0.8408 - val_accuracy: 0.8402 - lr: 5.4000e-05
# Epoch 43/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9923
# Epoch 43: saving model to SqueezeNet_sq_ratio_0.5_epoch_43.h5
# 149/149 [==============================] - 938s 6s/step - loss: 0.0325 - accuracy: 0.9923 - val_loss: 0.8983 - val_accuracy: 0.8330 - lr: 4.8000e-05
# Epoch 44/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9945
# Epoch 44: saving model to SqueezeNet_sq_ratio_0.5_epoch_44.h5
# 149/149 [==============================] - 940s 6s/step - loss: 0.0245 - accuracy: 0.9945 - val_loss: 0.9495 - val_accuracy: 0.8325 - lr: 4.2000e-05
# Epoch 45/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9951
# Epoch 45: saving model to SqueezeNet_sq_ratio_0.5_epoch_45.h5
# 149/149 [==============================] - 943s 6s/step - loss: 0.0222 - accuracy: 0.9951 - val_loss: 0.9902 - val_accuracy: 0.8317 - lr: 3.6000e-05
# Epoch 46/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9958
# Epoch 46: saving model to SqueezeNet_sq_ratio_0.5_epoch_46.h5
# 149/149 [==============================] - 943s 6s/step - loss: 0.0167 - accuracy: 0.9958 - val_loss: 0.9862 - val_accuracy: 0.8322 - lr: 3.0000e-05
# Epoch 47/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9972
# Epoch 47: saving model to SqueezeNet_sq_ratio_0.5_epoch_47.h5
# 149/149 [==============================] - 942s 6s/step - loss: 0.0146 - accuracy: 0.9972 - val_loss: 1.0131 - val_accuracy: 0.8345 - lr: 2.4000e-05
# Epoch 48/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9982
# Epoch 48: saving model to SqueezeNet_sq_ratio_0.5_epoch_48.h5
# 149/149 [==============================] - 942s 6s/step - loss: 0.0111 - accuracy: 0.9982 - val_loss: 1.0291 - val_accuracy: 0.8330 - lr: 1.8000e-05
# Epoch 49/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9985
# Epoch 49: saving model to SqueezeNet_sq_ratio_0.5_epoch_49.h5
# 149/149 [==============================] - 948s 6s/step - loss: 0.0090 - accuracy: 0.9985 - val_loss: 1.0325 - val_accuracy: 0.8322 - lr: 1.2000e-05
# Epoch 50/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9988
# Epoch 50: saving model to SqueezeNet_sq_ratio_0.5_epoch_50.h5
# 149/149 [==============================] - 904s 6s/step - loss: 0.0085 - accuracy: 0.9988 - val_loss: 1.0285 - val_accuracy: 0.8332 - lr: 6.0000e-06
# 61/61 [==============================] - 82s 1s/step
# Top-1 Accuracy of squeezenet_0.5 0.8335041
# Top-5 Accuracy of squeezenet_0.5 0.9833504
# save model 0.5
# squeeze ratio is 0.75
# Epoch 1/50
# 149/149 [==============================] - ETA: 0s - loss: 2.4425 - accuracy: 0.1044
# Epoch 1: saving model to SqueezeNet_sq_ratio_0.75_epoch_01.h5
# 149/149 [==============================] - 1147s 8s/step - loss: 2.4425 - accuracy: 0.1044 - val_loss: 2.3026 - val_accuracy: 0.0978 - lr: 3.0000e-04
# Epoch 2/50
# 149/149 [==============================] - ETA: 0s - loss: 2.2753 - accuracy: 0.1460
# Epoch 2: saving model to SqueezeNet_sq_ratio_0.75_epoch_02.h5
# 149/149 [==============================] - 1233s 8s/step - loss: 2.2753 - accuracy: 0.1460 - val_loss: 2.3025 - val_accuracy: 0.0989 - lr: 2.9400e-04
# Epoch 3/50
# 149/149 [==============================] - ETA: 0s - loss: 2.2643 - accuracy: 0.1501
# Epoch 3: saving model to SqueezeNet_sq_ratio_0.75_epoch_03.h5
# 149/149 [==============================] - 1248s 8s/step - loss: 2.2643 - accuracy: 0.1501 - val_loss: 2.2416 - val_accuracy: 0.1737 - lr: 2.8800e-04
# Epoch 4/50
# 149/149 [==============================] - ETA: 0s - loss: 2.2020 - accuracy: 0.1995
# Epoch 4: saving model to SqueezeNet_sq_ratio_0.75_epoch_04.h5
# ...
# Epoch 19/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.8393
# Epoch 19: saving model to SqueezeNet_sq_ratio_0.75_epoch_19.h5
# 149/149 [==============================] - 1284s 9s/step - loss: 0.4976 - accuracy: 0.8393 - val_loss: 0.7674 - val_accuracy: 0.7713 - lr: 1.9200e-04
# Epoch 20/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4777 - accuracy: 0.8440
# Epoch 20: saving model to SqueezeNet_sq_ratio_0.75_epoch_20.h5
# 149/149 [==============================] - 1287s 9s/step - loss: 0.4777 - accuracy: 0.8440 - val_loss: 0.7406 - val_accuracy: 0.7774 - lr: 1.8600e-04
# Epoch 21/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4270 - accuracy: 0.8684
# Epoch 21: saving model to SqueezeNet_sq_ratio_0.75_epoch_21.h5
# 149/149 [==============================] - 1290s 9s/step - loss: 0.4270 - accuracy: 0.8684 - val_loss: 0.6957 - val_accuracy: 0.7918 - lr: 1.8000e-04
# Epoch 22/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.8774
# Epoch 22: saving model to SqueezeNet_sq_ratio_0.75_epoch_22.h5
# 149/149 [==============================] - 1194s 8s/step - loss: 0.3915 - accuracy: 0.8774 - val_loss: 0.7056 - val_accuracy: 0.7884 - lr: 1.7400e-04
# Epoch 23/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8908
# Epoch 23: saving model to SqueezeNet_sq_ratio_0.75_epoch_23.h5
# 149/149 [==============================] - 1188s 8s/step - loss: 0.3470 - accuracy: 0.8908 - val_loss: 0.7377 - val_accuracy: 0.7902 - lr: 1.6800e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 0.9005
# Epoch 24: saving model to SqueezeNet_sq_ratio_0.75_epoch_24.h5
# 149/149 [==============================] - 1244s 8s/step - loss: 0.3163 - accuracy: 0.9005 - val_loss: 0.7340 - val_accuracy: 0.7884 - lr: 1.6200e-04
# Epoch 25/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.9053
# Epoch 25: saving model to SqueezeNet_sq_ratio_0.75_epoch_25.h5
# 149/149 [==============================] - 1107s 7s/step - loss: 0.3039 - accuracy: 0.9053 - val_loss: 0.8795 - val_accuracy: 0.7705 - lr: 1.5600e-04
# Epoch 26/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.9098
# Epoch 26: saving model to SqueezeNet_sq_ratio_0.75_epoch_26.h5
# 149/149 [==============================] - 1027s 7s/step - loss: 0.2803 - accuracy: 0.9098 - val_loss: 0.7743 - val_accuracy: 0.7933 - lr: 1.5000e-04
# Epoch 27/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9221
# Epoch 27: saving model to SqueezeNet_sq_ratio_0.75_epoch_27.h5
# 149/149 [==============================] - 1145s 8s/step - loss: 0.2430 - accuracy: 0.9221 - val_loss: 0.6966 - val_accuracy: 0.8105 - lr: 1.4400e-04
# Epoch 28/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9360
# Epoch 28: saving model to SqueezeNet_sq_ratio_0.75_epoch_28.h5
# 149/149 [==============================] - 1177s 8s/step - loss: 0.2086 - accuracy: 0.9360 - val_loss: 0.7695 - val_accuracy: 0.8007 - lr: 1.3800e-04
# Epoch 29/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.9310
# Epoch 29: saving model to SqueezeNet_sq_ratio_0.75_epoch_29.h5
# 149/149 [==============================] - 1190s 8s/step - loss: 0.2097 - accuracy: 0.9310 - val_loss: 0.7155 - val_accuracy: 0.8184 - lr: 1.3200e-04
# Epoch 30/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9449
# Epoch 30: saving model to SqueezeNet_sq_ratio_0.75_epoch_30.h5
# 149/149 [==============================] - 1200s 8s/step - loss: 0.1760 - accuracy: 0.9449 - val_loss: 0.7696 - val_accuracy: 0.7987 - lr: 1.2600e-04
# Epoch 31/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9514
# Epoch 31: saving model to SqueezeNet_sq_ratio_0.75_epoch_31.h5
# 149/149 [==============================] - 1164s 8s/step - loss: 0.1459 - accuracy: 0.9514 - val_loss: 0.8731 - val_accuracy: 0.8076 - lr: 1.2000e-04
# Epoch 32/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9572
# Epoch 32: saving model to SqueezeNet_sq_ratio_0.75_epoch_32.h5
# 149/149 [==============================] - 1241s 8s/step - loss: 0.1309 - accuracy: 0.9572 - val_loss: 0.8072 - val_accuracy: 0.8166 - lr: 1.1400e-04
# Epoch 33/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9630
# Epoch 33: saving model to SqueezeNet_sq_ratio_0.75_epoch_33.h5
# 149/149 [==============================] - 1212s 8s/step - loss: 0.1155 - accuracy: 0.9630 - val_loss: 0.9017 - val_accuracy: 0.8017 - lr: 1.0800e-04
# Epoch 34/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9687
# Epoch 34: saving model to SqueezeNet_sq_ratio_0.75_epoch_34.h5
# 149/149 [==============================] - 1180s 8s/step - loss: 0.0997 - accuracy: 0.9687 - val_loss: 0.8726 - val_accuracy: 0.8151 - lr: 1.0200e-04
# Epoch 35/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9683
# Epoch 35: saving model to SqueezeNet_sq_ratio_0.75_epoch_35.h5
# 149/149 [==============================] - 1324s 9s/step - loss: 0.0993 - accuracy: 0.9683 - val_loss: 0.9161 - val_accuracy: 0.8107 - lr: 9.6000e-05
# Epoch 36/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9704
# Epoch 36: saving model to SqueezeNet_sq_ratio_0.75_epoch_36.h5
# 149/149 [==============================] - 1253s 8s/step - loss: 0.0922 - accuracy: 0.9704 - val_loss: 0.9816 - val_accuracy: 0.8010 - lr: 9.0000e-05
# Epoch 37/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9768
# Epoch 37: saving model to SqueezeNet_sq_ratio_0.75_epoch_37.h5
# 149/149 [==============================] - 1257s 8s/step - loss: 0.0740 - accuracy: 0.9768 - val_loss: 0.9558 - val_accuracy: 0.8215 - lr: 8.4000e-05
# Epoch 38/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9888
# Epoch 38: saving model to SqueezeNet_sq_ratio_0.75_epoch_38.h5
# 149/149 [==============================] - 1196s 8s/step - loss: 0.0430 - accuracy: 0.9888 - val_loss: 1.1157 - val_accuracy: 0.7971 - lr: 7.8000e-05
# Epoch 39/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9874
# Epoch 39: saving model to SqueezeNet_sq_ratio_0.75_epoch_39.h5
# 149/149 [==============================] - 1316s 9s/step - loss: 0.0434 - accuracy: 0.9874 - val_loss: 1.0712 - val_accuracy: 0.8138 - lr: 7.2000e-05
# Epoch 40/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9900
# Epoch 40: saving model to SqueezeNet_sq_ratio_0.75_epoch_40.h5
# 149/149 [==============================] - 1317s 9s/step - loss: 0.0354 - accuracy: 0.9900 - val_loss: 1.0960 - val_accuracy: 0.8156 - lr: 6.6000e-05
# Epoch 41/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9943
# Epoch 41: saving model to SqueezeNet_sq_ratio_0.75_epoch_41.h5
# 149/149 [==============================] - 1301s 9s/step - loss: 0.0211 - accuracy: 0.9943 - val_loss: 1.0782 - val_accuracy: 0.8176 - lr: 6.0000e-05
# Epoch 42/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9960
# Epoch 42: saving model to SqueezeNet_sq_ratio_0.75_epoch_42.h5
# 149/149 [==============================] - 1201s 8s/step - loss: 0.0166 - accuracy: 0.9960 - val_loss: 1.1083 - val_accuracy: 0.8204 - lr: 5.4000e-05
# Epoch 43/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9980
# Epoch 43: saving model to SqueezeNet_sq_ratio_0.75_epoch_43.h5
# 149/149 [==============================] - 1322s 9s/step - loss: 0.0112 - accuracy: 0.9980 - val_loss: 1.2102 - val_accuracy: 0.8161 - lr: 4.8000e-05
# Epoch 44/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9982
# Epoch 44: saving model to SqueezeNet_sq_ratio_0.75_epoch_44.h5
# 149/149 [==============================] - 1210s 8s/step - loss: 0.0092 - accuracy: 0.9982 - val_loss: 1.1541 - val_accuracy: 0.8233 - lr: 4.2000e-05
# Epoch 45/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9991
# Epoch 45: saving model to SqueezeNet_sq_ratio_0.75_epoch_45.h5
# 149/149 [==============================] - 1260s 8s/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 1.1880 - val_accuracy: 0.8263 - lr: 3.6000e-05
# Epoch 46/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9995
# Epoch 46: saving model to SqueezeNet_sq_ratio_0.75_epoch_46.h5
# 149/149 [==============================] - 1349s 9s/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 1.2765 - val_accuracy: 0.8151 - lr: 3.0000e-05
# Epoch 47/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9995
# Epoch 47: saving model to SqueezeNet_sq_ratio_0.75_epoch_47.h5
# 149/149 [==============================] - 1396s 9s/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 1.2793 - val_accuracy: 0.8230 - lr: 2.4000e-05
# Epoch 48/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9998
# Epoch 48: saving model to SqueezeNet_sq_ratio_0.75_epoch_48.h5
# 149/149 [==============================] - 1446s 10s/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 1.2906 - val_accuracy: 0.8274 - lr: 1.8000e-05
# Epoch 49/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9999
# Epoch 49: saving model to SqueezeNet_sq_ratio_0.75_epoch_49.h5
# 149/149 [==============================] - 1535s 10s/step - loss: 0.0024 - accuracy: 0.9999 - val_loss: 1.3320 - val_accuracy: 0.8217 - lr: 1.2000e-05
# Epoch 50/50
# 149/149 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9999
# Epoch 50: saving model to SqueezeNet_sq_ratio_0.75_epoch_50.h5
# 149/149 [==============================] - 1470s 10s/step - loss: 0.0021 - accuracy: 0.9999 - val_loss: 1.3295 - val_accuracy: 0.8235 - lr: 6.0000e-06
# 61/61 [==============================] - 196s 3s/step
# Top-1 Accuracy of squeezenet_0.75 0.82428277
# Top-5 Accuracy of squeezenet_0.75 0.9833504
# save model 0.75
# squeeze ratio is 1
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 22
#      15 checkpoint_callback = ModelCheckpoint(
#      16     filepath="SqueezeNet_sq_ratio_{}_epoch_{{epoch:02d}}.h5".format(r),
#      17     save_freq='epoch',
#      18     verbose=1
#      19 )
#      21 # --- Training ---
# ---> 22 training_history = model.fit(
#      23     train_generator,
#      24     epochs=total_epochs,
#      25     steps_per_epoch=steps_per_epoch,
#      26     validation_data=val_generator,
#      27     validation_steps=val_generator.samples // batch_size,
#      28     callbacks=[lr_callback, checkpoint_callback, tensorboard_callback],
#      29     verbose=1
#      30 )
#      31 model.save_weights(f'Squeeze_net_ratio_trial_{r}.h5')
#      35 val_steps = val_generator1.samples // batch_size
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:959, in Function._call(self, *args, **kwds)
#     955     pass  # Fall through to cond-based initialization.
#     956   else:
#     957     # Lifting succeeded, so variables are initialized and we can run the
#     958     # no_variable_creation function.
# --> 959     return self._no_variable_creation_fn(*args, **kwds)
#     960 else:
#     961   _, _, filtered_flat_args = (
#     962       self._variable_creation_fn._function_spec  # pylint: disable=protected-access
#     963       .canonicalize_function_inputs(
#     964           args, kwds))
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File c:\Users\deepe\anaconda3\envs\newenv\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# We verify the accuracy

# %%
for r in [0.125,0.25,0.5,0.75]:
    print("\n")
    print('squeeze ratio is', r)
    sqnet=SqueezeNet(squeeze_ratio=r)
    model = sqnet.build_model(input_shape=input_shape, n_classes=10, choice='bypass')
    model.load_weights(f'Squeeze_net_ratio_trial_{r}.h5')
    val_steps = val_generator1.samples // batch_size
    predictions = model.predict(val_generator1, steps=val_steps)

    true_labels = val_generator1.classes[:val_steps * batch_size]

    num_classes = len(val_generator1.class_indices)
    true_labels_one_hot = tf.keras.utils.to_categorical(true_labels, num_classes)


    top1_metric = tf.keras.metrics.CategoricalAccuracy()
    top5_metric = tf.keras.metrics.TopKCategoricalAccuracy(k=5)
    top1_metric.update_state(true_labels_one_hot, predictions)
    top5_metric.update_state(true_labels_one_hot, predictions)

    print(f"Top-1 Accuracy of squeezenet_{r}", top1_metric.result().numpy())
    print(f"Top-5 Accuracy of squeezenet_{r}", top5_metric.result().numpy())
# Out:
# squeeze ratio is 0.125
# 61/61 [==============================] - 40s 648ms/step
# Top-1 Accuracy of squeezenet_0.125 0.8122439
# Top-5 Accuracy of squeezenet_0.125 0.9836066
#
#
# squeeze ratio is 0.25
# 61/61 [==============================] - 56s 914ms/step
# Top-1 Accuracy of squeezenet_0.25 0.81813526
# Top-5 Accuracy of squeezenet_0.25 0.98181355
#
#
# squeeze ratio is 0.5
# 61/61 [==============================] - 106s 2s/step
# Top-1 Accuracy of squeezenet_0.5 0.8335041
# Top-5 Accuracy of squeezenet_0.5 0.9833504
#
#
# squeeze ratio is 0.75
# 61/61 [==============================] - 193s 3s/step
# Top-1 Accuracy of squeezenet_0.75 0.82428277
# Top-5 Accuracy of squeezenet_0.75 0.9833504
