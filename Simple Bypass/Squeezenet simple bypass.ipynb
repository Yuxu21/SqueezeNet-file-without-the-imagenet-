# %%
import keras
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import h5py

from tensorflow.keras import Model, Sequential

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Concatenate, Convolution2D, GlobalAveragePooling2D, Layer, Add, MaxPool2D

from keras.callbacks import TensorBoard

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras import regularizers

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# We import the training and validation data

# %%
train_dir = '../imagenet2/imagenet2/train'
val_dir = '../imagenet2/imagenet2/val'
batch_size=64
def random_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = np.random.randint(0, h - crop_size + 1)
    left = np.random.randint(0, w - crop_size + 1)
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped

train_datagen = ImageDataGenerator(
    rescale=1.,
    horizontal_flip=True,
    preprocessing_function=random_crop_preprocessing
)

def center_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = (h - crop_size) // 2
    left = (w - crop_size) // 2
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped

val_datagen = ImageDataGenerator(
    rescale=1.,
    preprocessing_function=center_crop_preprocessing
)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator1 = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 9559 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.

# %% [markdown]
# We define the Squeezenet class with Vanilla model and model with bypass

# %%
one = (1, 1)
two = (2, 2)
three = (3, 3)
five = (5, 5)
seven = (7, 7)
thirteen = (13, 13)

input_shape = (227, 227, 3)
class FireModule(object):

    def __init__(self, layer_number: int, activation: str, kernel_initializer: str) -> None:
        self.layer_number = layer_number
        self.activation = activation
        self.kernel_initializer = kernel_initializer

    def build_module(self, fire_input: Layer) -> Layer:
        global one, three, five

        output_size = 128 * (1 + (self.layer_number//2))

        squeeze_1x1_filters = 16 * (1 + (self.layer_number//2))
        expand_1x1_filters = expand_3x3_filters = output_size//2

        squeeze_1x1 = Conv2D(name=f'fire_{self.layer_number+2}_squeeze_1x1',
            filters=squeeze_1x1_filters, kernel_size=one, strides=1, padding='valid', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(fire_input)
        expand_1x1 = Conv2D(name=f'fire_{self.layer_number+2}_expand_1x1',
            filters=expand_1x1_filters, kernel_size=one, strides=1, padding='valid', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(squeeze_1x1)
        expand_3x3 = Conv2D(name=f'fire_{self.layer_number+2}_expand_3x3',
            filters=expand_3x3_filters, kernel_size=three, strides=1, padding='same', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(squeeze_1x1)

        fire = Concatenate(name=f'fire_{self.layer_number+2}')([expand_1x1, expand_3x3])

        return fire
class SqueezeNet(object):

    def __init__(self, activation: str='relu', kernel_initializer: str='glorot_uniform') -> None:


        self.activation = activation
        self.kernel_initializer = kernel_initializer

    def vanilla_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000) -> None:


        inp = Input(shape=input_shape, name='Input')

        conv_1 = Conv2D(name="Conv_1",
            filters=96, kernel_size=seven, strides=2, padding='same', activation=self.activation, kernel_initializer=self.kernel_initializer)(inp)
        maxpool_1 = MaxPool2D(name="MaxPool_1",
            pool_size=three, strides=2)(conv_1)

        fire_2 = FireModule(layer_number=0, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_1)
        fire_3 = FireModule(layer_number=1, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_2)
        fire_4 = FireModule(layer_number=2, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_3)

        maxpool_2 = MaxPool2D(name="MaxPool_2",
            pool_size=three, strides=2)(fire_4)

        fire_5 = FireModule(layer_number=3, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_2)
        fire_6 = FireModule(layer_number=4, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_5)
        fire_7 = FireModule(layer_number=5, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_6)
        fire_8 = FireModule(layer_number=6, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_7)

        maxpool_3 = MaxPool2D(name="MaxPool_3",
            pool_size=three, strides=2)(fire_8)

        fire_9 = FireModule(layer_number=7, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_3)

        dropout = Dropout(0.5, name="Dropout")(fire_9)

        conv_10 = Conv2D(name="Conv_10",
            filters=10, kernel_size=one, strides=1, padding='valid', activation=self.activation, kernel_initializer=self.kernel_initializer)(dropout)
        gap_11 = GlobalAveragePooling2D()(conv_10)
        out = Activation('softmax', name='softmax')(gap_11)
        self.model = Model(inputs=inp, outputs=out)


    def bypass_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000) -> None:

        inp = Input(shape=input_shape, name='Input')

        conv_1 = Conv2D(name="Conv_1",
            filters=96, kernel_size=seven, strides=2, padding='same', activation=self.activation, kernel_initializer=self.kernel_initializer)(inp)
        maxpool_1 = MaxPool2D(name="MaxPool_1",
            pool_size=three, strides=2)(conv_1)

        fire_2 = FireModule(layer_number=0, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_1)
        fire_3 = FireModule(layer_number=1, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_2)
        bypass_1 = Add(name="Bypass_1")([fire_2, fire_3])
        fire_4 = FireModule(layer_number=2, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(bypass_1)

        maxpool_2 = MaxPool2D(name="MaxPool_2",
            pool_size=three, strides=2)(fire_4)

        fire_5 = FireModule(layer_number=3, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_2)
        bypass_2 = Add(name="Bypass_2")([maxpool_2, fire_5])
        fire_6 = FireModule(layer_number=4, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(bypass_2)
        fire_7 = FireModule(layer_number=5, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_6)
        bypass_3 = Add(name="Bypass_3")([fire_6, fire_7])
        fire_8 = FireModule(layer_number=6, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(bypass_3)

        maxpool_3 = MaxPool2D(name="MaxPool_3",
            pool_size=three, strides=2)(fire_8)

        fire_9 = FireModule(layer_number=7, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_3)
        bypass_4 = Add(name="Bypass_4")([maxpool_3, fire_9])

        dropout = Dropout(0.5, name="Dropout")(bypass_4)

        conv_10 = Conv2D(name="Conv_10",
            filters=10, kernel_size=one, strides=1, padding='valid', activation=self.activation, kernel_initializer=self.kernel_initializer)(dropout)
        gap_11 = GlobalAveragePooling2D()(conv_10)
        out = Activation('softmax', name='softmax')(gap_11)

        self.model = Model(inputs=inp, outputs=out)


    def build_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000, choice: str='vanilla') -> Model:
        if choice == "vanilla":
            self.vanilla_model(input_shape, n_classes)
        else:
            self.bypass_model(input_shape, n_classes)

        return self.model

# %% [markdown]
# We define the training parameters

# %%
base_lr=0.0003
batch_size=64
steps_per_epoch = train_generator.samples // batch_size
total_epochs = 50

def poly_lr_scheduler(epoch, lr):
    decay = 1.0 - (epoch / total_epochs)
    new_lr = base_lr * decay
    return new_lr

lr_callback = LearningRateScheduler(poly_lr_scheduler)
tensorboard_callback = TensorBoard(log_dir='./logs')
checkpoint_callback = ModelCheckpoint(
    filepath="squeezenet_bypass_checkpoint_epoch_{epoch:02d}.h5",
    save_freq='epoch',
    verbose=1
)

checkpoint_callback = ModelCheckpoint(
    filepath="SqueezeNet_bypass_epoch_{epoch:02d}.h5",
    save_freq='epoch',
    verbose=1
)

# %% [markdown]
# We train the Squeezenet model with bypass

# %%
sqnet = SqueezeNet()
model_sq_bypass = sqnet.build_model(input_shape=input_shape, n_classes=10, choice='bypass')
model_sq_bypass.compile(optimizer= tf.keras.optimizers.Adam(base_lr),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])


sq_bypass_history = model_sq_bypass.fit(
    train_generator,
    epochs=total_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size,
    callbacks=[lr_callback, checkpoint_callback, tensorboard_callback],
    verbose=1
)
# Out:
# Epoch 1/50
# 149/149 [==============================] - ETA: 0s - loss: 2.1844 - accuracy: 0.2072
# Epoch 1: saving model to SqueezeNet_bypass_epoch_01.h5
# 149/149 [==============================] - 450s 3s/step - loss: 2.1844 - accuracy: 0.2072 - val_loss: 2.0141 - val_accuracy: 0.3076 - lr: 3.0000e-04
# Epoch 2/50
# 149/149 [==============================] - ETA: 0s - loss: 1.8781 - accuracy: 0.3448
# Epoch 2: saving model to SqueezeNet_bypass_epoch_02.h5
# 149/149 [==============================] - 389s 3s/step - loss: 1.8781 - accuracy: 0.3448 - val_loss: 1.7634 - val_accuracy: 0.3668 - lr: 2.9400e-04
# Epoch 3/50
# 149/149 [==============================] - ETA: 0s - loss: 1.6629 - accuracy: 0.4314
# Epoch 3: saving model to SqueezeNet_bypass_epoch_03.h5
# 149/149 [==============================] - 381s 3s/step - loss: 1.6629 - accuracy: 0.4314 - val_loss: 1.5276 - val_accuracy: 0.4823 - lr: 2.8800e-04
# Epoch 4/50
# 149/149 [==============================] - ETA: 0s - loss: 1.5003 - accuracy: 0.5013
# Epoch 4: saving model to SqueezeNet_bypass_epoch_04.h5
# 149/149 [==============================] - 381s 3s/step - loss: 1.5003 - accuracy: 0.5013 - val_loss: 1.3669 - val_accuracy: 0.5638 - lr: 2.8200e-04
# Epoch 5/50
# 149/149 [==============================] - ETA: 0s - loss: 1.3497 - accuracy: 0.5545
# Epoch 5: saving model to SqueezeNet_bypass_epoch_05.h5
# 149/149 [==============================] - 385s 3s/step - loss: 1.3497 - accuracy: 0.5545 - val_loss: 1.3349 - val_accuracy: 0.5589 - lr: 2.7600e-04
# Epoch 6/50
# 149/149 [==============================] - ETA: 0s - loss: 1.2204 - accuracy: 0.6006
# Epoch 6: saving model to SqueezeNet_bypass_epoch_06.h5
# 149/149 [==============================] - 390s 3s/step - loss: 1.2204 - accuracy: 0.6006 - val_loss: 1.1969 - val_accuracy: 0.6173 - lr: 2.7000e-04
# Epoch 7/50
# 149/149 [==============================] - ETA: 0s - loss: 1.1279 - accuracy: 0.6329
# Epoch 7: saving model to SqueezeNet_bypass_epoch_07.h5
# 149/149 [==============================] - 382s 3s/step - loss: 1.1279 - accuracy: 0.6329 - val_loss: 1.1349 - val_accuracy: 0.6478 - lr: 2.6400e-04
# Epoch 8/50
# 149/149 [==============================] - ETA: 0s - loss: 1.0483 - accuracy: 0.6602
# Epoch 8: saving model to SqueezeNet_bypass_epoch_08.h5
# 149/149 [==============================] - 381s 3s/step - loss: 1.0483 - accuracy: 0.6602 - val_loss: 1.0508 - val_accuracy: 0.6660 - lr: 2.5800e-04
# Epoch 9/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9711 - accuracy: 0.6850
# Epoch 9: saving model to SqueezeNet_bypass_epoch_09.h5
# 149/149 [==============================] - 390s 3s/step - loss: 0.9711 - accuracy: 0.6850 - val_loss: 1.0361 - val_accuracy: 0.6668 - lr: 2.5200e-04
# Epoch 10/50
# 149/149 [==============================] - ETA: 0s - loss: 0.9252 - accuracy: 0.7045
# Epoch 10: saving model to SqueezeNet_bypass_epoch_10.h5
# 149/149 [==============================] - 414s 3s/step - loss: 0.9252 - accuracy: 0.7045 - val_loss: 0.9838 - val_accuracy: 0.6931 - lr: 2.4600e-04
# Epoch 11/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8782 - accuracy: 0.7204
# Epoch 11: saving model to SqueezeNet_bypass_epoch_11.h5
# 149/149 [==============================] - 433s 3s/step - loss: 0.8782 - accuracy: 0.7204 - val_loss: 0.9030 - val_accuracy: 0.7152 - lr: 2.4000e-04
# Epoch 12/50
# 149/149 [==============================] - ETA: 0s - loss: 0.8140 - accuracy: 0.7374
# Epoch 12: saving model to SqueezeNet_bypass_epoch_12.h5
# 149/149 [==============================] - 424s 3s/step - loss: 0.8140 - accuracy: 0.7374 - val_loss: 0.8790 - val_accuracy: 0.7234 - lr: 2.3400e-04
# Epoch 13/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7783 - accuracy: 0.7512
# Epoch 13: saving model to SqueezeNet_bypass_epoch_13.h5
# 149/149 [==============================] - 423s 3s/step - loss: 0.7783 - accuracy: 0.7512 - val_loss: 0.8573 - val_accuracy: 0.7349 - lr: 2.2800e-04
# Epoch 14/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7468 - accuracy: 0.7620
# Epoch 14: saving model to SqueezeNet_bypass_epoch_14.h5
# 149/149 [==============================] - 424s 3s/step - loss: 0.7468 - accuracy: 0.7620 - val_loss: 0.8456 - val_accuracy: 0.7382 - lr: 2.2200e-04
# Epoch 15/50
# 149/149 [==============================] - ETA: 0s - loss: 0.7186 - accuracy: 0.7701
# Epoch 15: saving model to SqueezeNet_bypass_epoch_15.h5
# 149/149 [==============================] - 416s 3s/step - loss: 0.7186 - accuracy: 0.7701 - val_loss: 0.8396 - val_accuracy: 0.7405 - lr: 2.1600e-04
# Epoch 16/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6838 - accuracy: 0.7819
# Epoch 16: saving model to SqueezeNet_bypass_epoch_16.h5
# 149/149 [==============================] - 421s 3s/step - loss: 0.6838 - accuracy: 0.7819 - val_loss: 0.7677 - val_accuracy: 0.7559 - lr: 2.1000e-04
# Epoch 17/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6721 - accuracy: 0.7830
# Epoch 17: saving model to SqueezeNet_bypass_epoch_17.h5
# 149/149 [==============================] - 420s 3s/step - loss: 0.6721 - accuracy: 0.7830 - val_loss: 0.7735 - val_accuracy: 0.7541 - lr: 2.0400e-04
# Epoch 18/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.8014
# Epoch 18: saving model to SqueezeNet_bypass_epoch_18.h5
# 149/149 [==============================] - 425s 3s/step - loss: 0.6304 - accuracy: 0.8014 - val_loss: 0.8222 - val_accuracy: 0.7462 - lr: 1.9800e-04
# Epoch 19/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6114 - accuracy: 0.8051
# Epoch 19: saving model to SqueezeNet_bypass_epoch_19.h5
# 149/149 [==============================] - 431s 3s/step - loss: 0.6114 - accuracy: 0.8051 - val_loss: 0.7603 - val_accuracy: 0.7587 - lr: 1.9200e-04
# Epoch 20/50
# 149/149 [==============================] - ETA: 0s - loss: 0.6066 - accuracy: 0.8071
# Epoch 20: saving model to SqueezeNet_bypass_epoch_20.h5
# 149/149 [==============================] - 426s 3s/step - loss: 0.6066 - accuracy: 0.8071 - val_loss: 0.7483 - val_accuracy: 0.7631 - lr: 1.8600e-04
# Epoch 21/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5566 - accuracy: 0.8250
# Epoch 21: saving model to SqueezeNet_bypass_epoch_21.h5
# 149/149 [==============================] - 418s 3s/step - loss: 0.5566 - accuracy: 0.8250 - val_loss: 0.8529 - val_accuracy: 0.7390 - lr: 1.8000e-04
# Epoch 22/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.8223
# Epoch 22: saving model to SqueezeNet_bypass_epoch_22.h5
# 149/149 [==============================] - 419s 3s/step - loss: 0.5475 - accuracy: 0.8223 - val_loss: 0.7895 - val_accuracy: 0.7554 - lr: 1.7400e-04
# Epoch 23/50
# 149/149 [==============================] - ETA: 0s - loss: 0.5378 - accuracy: 0.8274
# Epoch 23: saving model to SqueezeNet_bypass_epoch_23.h5
# 149/149 [==============================] - 417s 3s/step - loss: 0.5378 - accuracy: 0.8274 - val_loss: 0.7324 - val_accuracy: 0.7820 - lr: 1.6800e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.8442
# Epoch 24: saving model to SqueezeNet_bypass_epoch_24.h5
# 149/149 [==============================] - 419s 3s/step - loss: 0.4932 - accuracy: 0.8442 - val_loss: 0.7132 - val_accuracy: 0.7743 - lr: 1.6200e-04
# Epoch 25/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4773 - accuracy: 0.8419
# Epoch 25: saving model to SqueezeNet_bypass_epoch_25.h5
# 149/149 [==============================] - 429s 3s/step - loss: 0.4773 - accuracy: 0.8419 - val_loss: 0.7853 - val_accuracy: 0.7567 - lr: 1.5600e-04
# Epoch 26/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4596 - accuracy: 0.8526
# Epoch 26: saving model to SqueezeNet_bypass_epoch_26.h5
# 149/149 [==============================] - 417s 3s/step - loss: 0.4596 - accuracy: 0.8526 - val_loss: 0.7051 - val_accuracy: 0.7907 - lr: 1.5000e-04
# Epoch 27/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4338 - accuracy: 0.8620
# Epoch 27: saving model to SqueezeNet_bypass_epoch_27.h5
# 149/149 [==============================] - 429s 3s/step - loss: 0.4338 - accuracy: 0.8620 - val_loss: 0.7949 - val_accuracy: 0.7759 - lr: 1.4400e-04
# Epoch 28/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4416 - accuracy: 0.8581
# Epoch 28: saving model to SqueezeNet_bypass_epoch_28.h5
# 149/149 [==============================] - 425s 3s/step - loss: 0.4416 - accuracy: 0.8581 - val_loss: 0.6922 - val_accuracy: 0.7964 - lr: 1.3800e-04
# Epoch 29/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.8726
# Epoch 29: saving model to SqueezeNet_bypass_epoch_29.h5
# 149/149 [==============================] - 409s 3s/step - loss: 0.3940 - accuracy: 0.8726 - val_loss: 0.6871 - val_accuracy: 0.7997 - lr: 1.3200e-04
# Epoch 30/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3995 - accuracy: 0.8680
# Epoch 30: saving model to SqueezeNet_bypass_epoch_30.h5
# 149/149 [==============================] - 451s 3s/step - loss: 0.3995 - accuracy: 0.8680 - val_loss: 0.7203 - val_accuracy: 0.7902 - lr: 1.2600e-04
# Epoch 31/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.8823
# Epoch 31: saving model to SqueezeNet_bypass_epoch_31.h5
# 149/149 [==============================] - 393s 3s/step - loss: 0.3631 - accuracy: 0.8823 - val_loss: 0.7793 - val_accuracy: 0.7874 - lr: 1.2000e-04
# Epoch 32/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3624 - accuracy: 0.8809
# Epoch 32: saving model to SqueezeNet_bypass_epoch_32.h5
# 149/149 [==============================] - 386s 3s/step - loss: 0.3624 - accuracy: 0.8809 - val_loss: 0.7202 - val_accuracy: 0.7877 - lr: 1.1400e-04
# Epoch 33/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8887
# Epoch 33: saving model to SqueezeNet_bypass_epoch_33.h5
# 149/149 [==============================] - 393s 3s/step - loss: 0.3438 - accuracy: 0.8887 - val_loss: 0.7362 - val_accuracy: 0.7951 - lr: 1.0800e-04
# Epoch 34/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3287 - accuracy: 0.8948
# Epoch 34: saving model to SqueezeNet_bypass_epoch_34.h5
# 149/149 [==============================] - 388s 3s/step - loss: 0.3287 - accuracy: 0.8948 - val_loss: 0.7020 - val_accuracy: 0.8053 - lr: 1.0200e-04
# Epoch 35/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.8966
# Epoch 35: saving model to SqueezeNet_bypass_epoch_35.h5
# 149/149 [==============================] - 402s 3s/step - loss: 0.3147 - accuracy: 0.8966 - val_loss: 0.7300 - val_accuracy: 0.7943 - lr: 9.6000e-05
# Epoch 36/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.8983
# Epoch 36: saving model to SqueezeNet_bypass_epoch_36.h5
# 149/149 [==============================] - 390s 3s/step - loss: 0.3065 - accuracy: 0.8983 - val_loss: 0.6640 - val_accuracy: 0.8117 - lr: 9.0000e-05
# Epoch 37/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2775 - accuracy: 0.9123
# Epoch 37: saving model to SqueezeNet_bypass_epoch_37.h5
# 149/149 [==============================] - 404s 3s/step - loss: 0.2775 - accuracy: 0.9123 - val_loss: 0.7230 - val_accuracy: 0.8092 - lr: 8.4000e-05
# Epoch 38/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.9129
# Epoch 38: saving model to SqueezeNet_bypass_epoch_38.h5
# 149/149 [==============================] - 392s 3s/step - loss: 0.2699 - accuracy: 0.9129 - val_loss: 0.7527 - val_accuracy: 0.7959 - lr: 7.8000e-05
# Epoch 39/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.9165
# Epoch 39: saving model to SqueezeNet_bypass_epoch_39.h5
# 149/149 [==============================] - 389s 3s/step - loss: 0.2624 - accuracy: 0.9165 - val_loss: 0.7261 - val_accuracy: 0.8097 - lr: 7.2000e-05
# Epoch 40/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.9215
# Epoch 40: saving model to SqueezeNet_bypass_epoch_40.h5
# 149/149 [==============================] - 398s 3s/step - loss: 0.2374 - accuracy: 0.9215 - val_loss: 0.7040 - val_accuracy: 0.8133 - lr: 6.6000e-05
# Epoch 41/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9291
# Epoch 41: saving model to SqueezeNet_bypass_epoch_41.h5
# 149/149 [==============================] - 395s 3s/step - loss: 0.2218 - accuracy: 0.9291 - val_loss: 0.7253 - val_accuracy: 0.8115 - lr: 6.0000e-05
# Epoch 42/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2213 - accuracy: 0.9290
# Epoch 42: saving model to SqueezeNet_bypass_epoch_42.h5
# 149/149 [==============================] - 422s 3s/step - loss: 0.2213 - accuracy: 0.9290 - val_loss: 0.7576 - val_accuracy: 0.8066 - lr: 5.4000e-05
# Epoch 43/50
# 149/149 [==============================] - ETA: 0s - loss: 0.2071 - accuracy: 0.9335
# Epoch 43: saving model to SqueezeNet_bypass_epoch_43.h5
# 149/149 [==============================] - 433s 3s/step - loss: 0.2071 - accuracy: 0.9335 - val_loss: 0.7634 - val_accuracy: 0.8087 - lr: 4.8000e-05
# Epoch 44/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9385
# Epoch 44: saving model to SqueezeNet_bypass_epoch_44.h5
# 149/149 [==============================] - 398s 3s/step - loss: 0.1947 - accuracy: 0.9385 - val_loss: 0.7306 - val_accuracy: 0.8169 - lr: 4.2000e-05
# Epoch 45/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9408
# Epoch 45: saving model to SqueezeNet_bypass_epoch_45.h5
# 149/149 [==============================] - 395s 3s/step - loss: 0.1857 - accuracy: 0.9408 - val_loss: 0.7904 - val_accuracy: 0.8079 - lr: 3.6000e-05
# Epoch 46/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.9452
# Epoch 46: saving model to SqueezeNet_bypass_epoch_46.h5
# 149/149 [==============================] - 392s 3s/step - loss: 0.1726 - accuracy: 0.9452 - val_loss: 0.7672 - val_accuracy: 0.8074 - lr: 3.0000e-05
# Epoch 47/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9500
# Epoch 47: saving model to SqueezeNet_bypass_epoch_47.h5
# 149/149 [==============================] - 389s 3s/step - loss: 0.1639 - accuracy: 0.9500 - val_loss: 0.7544 - val_accuracy: 0.8148 - lr: 2.4000e-05
# Epoch 48/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.9522
# Epoch 48: saving model to SqueezeNet_bypass_epoch_48.h5
# 149/149 [==============================] - 390s 3s/step - loss: 0.1494 - accuracy: 0.9522 - val_loss: 0.7889 - val_accuracy: 0.8138 - lr: 1.8000e-05
# Epoch 49/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 0.9558
# Epoch 49: saving model to SqueezeNet_bypass_epoch_49.h5
# 149/149 [==============================] - 393s 3s/step - loss: 0.1433 - accuracy: 0.9558 - val_loss: 0.7910 - val_accuracy: 0.8161 - lr: 1.2000e-05
# Epoch 50/50
# 149/149 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9575
# Epoch 50: saving model to SqueezeNet_bypass_epoch_50.h5
# 149/149 [==============================] - 427s 3s/step - loss: 0.1383 - accuracy: 0.9575 - val_loss: 0.7806 - val_accuracy: 0.8184 - lr: 6.0000e-06

# %%
model_sq_bypass.save_weights('Squeezenet_bypass.h5')

# %%
model_sq_bypass.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 227, 227, 3  0           []
#                                 )]
#
#  Conv_1 (Conv2D)                (None, 114, 114, 96  14208       ['Input[0][0]']
#                                 )
#
#  MaxPool_1 (MaxPooling2D)       (None, 56, 56, 96)   0           ['Conv_1[0][0]']
#
#  fire_2_squeeze_1x1 (Conv2D)    (None, 56, 56, 16)   1552        ['MaxPool_1[0][0]']
#
#  fire_2_expand_1x1 (Conv2D)     (None, 56, 56, 64)   1088        ['fire_2_squeeze_1x1[0][0]']
#
#  fire_2_expand_3x3 (Conv2D)     (None, 56, 56, 64)   9280        ['fire_2_squeeze_1x1[0][0]']
#
#  fire_2 (Concatenate)           (None, 56, 56, 128)  0           ['fire_2_expand_1x1[0][0]',
#                                                                   'fire_2_expand_3x3[0][0]']
#
#  fire_3_squeeze_1x1 (Conv2D)    (None, 56, 56, 16)   2064        ['fire_2[0][0]']
#
#  fire_3_expand_1x1 (Conv2D)     (None, 56, 56, 64)   1088        ['fire_3_squeeze_1x1[0][0]']
#
#  fire_3_expand_3x3 (Conv2D)     (None, 56, 56, 64)   9280        ['fire_3_squeeze_1x1[0][0]']
#
#  fire_3 (Concatenate)           (None, 56, 56, 128)  0           ['fire_3_expand_1x1[0][0]',
#                                                                   'fire_3_expand_3x3[0][0]']
#
#  Bypass_1 (Add)                 (None, 56, 56, 128)  0           ['fire_2[0][0]',
#                                                                   'fire_3[0][0]']
#
#  fire_4_squeeze_1x1 (Conv2D)    (None, 56, 56, 32)   4128        ['Bypass_1[0][0]']
#
#  fire_4_expand_1x1 (Conv2D)     (None, 56, 56, 128)  4224        ['fire_4_squeeze_1x1[0][0]']
#
#  fire_4_expand_3x3 (Conv2D)     (None, 56, 56, 128)  36992       ['fire_4_squeeze_1x1[0][0]']
#
#  fire_4 (Concatenate)           (None, 56, 56, 256)  0           ['fire_4_expand_1x1[0][0]',
#                                                                   'fire_4_expand_3x3[0][0]']
#
#  MaxPool_2 (MaxPooling2D)       (None, 27, 27, 256)  0           ['fire_4[0][0]']
#
#  fire_5_squeeze_1x1 (Conv2D)    (None, 27, 27, 32)   8224        ['MaxPool_2[0][0]']
#
#  fire_5_expand_1x1 (Conv2D)     (None, 27, 27, 128)  4224        ['fire_5_squeeze_1x1[0][0]']
#
#  fire_5_expand_3x3 (Conv2D)     (None, 27, 27, 128)  36992       ['fire_5_squeeze_1x1[0][0]']
#
#  fire_5 (Concatenate)           (None, 27, 27, 256)  0           ['fire_5_expand_1x1[0][0]',
#                                                                   'fire_5_expand_3x3[0][0]']
#
#  Bypass_2 (Add)                 (None, 27, 27, 256)  0           ['MaxPool_2[0][0]',
#                                                                   'fire_5[0][0]']
#
#  fire_6_squeeze_1x1 (Conv2D)    (None, 27, 27, 48)   12336       ['Bypass_2[0][0]']
#
#  fire_6_expand_1x1 (Conv2D)     (None, 27, 27, 192)  9408        ['fire_6_squeeze_1x1[0][0]']
#
#  fire_6_expand_3x3 (Conv2D)     (None, 27, 27, 192)  83136       ['fire_6_squeeze_1x1[0][0]']
#
#  fire_6 (Concatenate)           (None, 27, 27, 384)  0           ['fire_6_expand_1x1[0][0]',
#                                                                   'fire_6_expand_3x3[0][0]']
#
#  fire_7_squeeze_1x1 (Conv2D)    (None, 27, 27, 48)   18480       ['fire_6[0][0]']
#
#  fire_7_expand_1x1 (Conv2D)     (None, 27, 27, 192)  9408        ['fire_7_squeeze_1x1[0][0]']
#
#  fire_7_expand_3x3 (Conv2D)     (None, 27, 27, 192)  83136       ['fire_7_squeeze_1x1[0][0]']
#
#  fire_7 (Concatenate)           (None, 27, 27, 384)  0           ['fire_7_expand_1x1[0][0]',
#                                                                   'fire_7_expand_3x3[0][0]']
#
#  Bypass_3 (Add)                 (None, 27, 27, 384)  0           ['fire_6[0][0]',
#                                                                   'fire_7[0][0]']
#
#  fire_8_squeeze_1x1 (Conv2D)    (None, 27, 27, 64)   24640       ['Bypass_3[0][0]']
#
#  fire_8_expand_1x1 (Conv2D)     (None, 27, 27, 256)  16640       ['fire_8_squeeze_1x1[0][0]']
#
#  fire_8_expand_3x3 (Conv2D)     (None, 27, 27, 256)  147712      ['fire_8_squeeze_1x1[0][0]']
#
#  fire_8 (Concatenate)           (None, 27, 27, 512)  0           ['fire_8_expand_1x1[0][0]',
#                                                                   'fire_8_expand_3x3[0][0]']
#
#  MaxPool_3 (MaxPooling2D)       (None, 13, 13, 512)  0           ['fire_8[0][0]']
#
#  fire_9_squeeze_1x1 (Conv2D)    (None, 13, 13, 64)   32832       ['MaxPool_3[0][0]']
#
#  fire_9_expand_1x1 (Conv2D)     (None, 13, 13, 256)  16640       ['fire_9_squeeze_1x1[0][0]']
#
#  fire_9_expand_3x3 (Conv2D)     (None, 13, 13, 256)  147712      ['fire_9_squeeze_1x1[0][0]']
#
#  fire_9 (Concatenate)           (None, 13, 13, 512)  0           ['fire_9_expand_1x1[0][0]',
#                                                                   'fire_9_expand_3x3[0][0]']
#
#  Bypass_4 (Add)                 (None, 13, 13, 512)  0           ['MaxPool_3[0][0]',
#                                                                   'fire_9[0][0]']
#
#  Dropout (Dropout)              (None, 13, 13, 512)  0           ['Bypass_4[0][0]']
#
#  Conv_10 (Conv2D)               (None, 13, 13, 10)   5130        ['Dropout[0][0]']
#
#  global_average_pooling2d (Glob  (None, 10)          0           ['Conv_10[0][0]']
#  alAveragePooling2D)
#
#  softmax (Activation)           (None, 10)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 740,554
# Trainable params: 740,554
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
sqnet = SqueezeNet()
model_bp_load = sqnet.build_model(input_shape=input_shape, n_classes=10, choice='bypass')
model_bp_load.load_weights('Squeezenet_bypass.h5')

# %% [markdown]
# We verify the accuracy

# %%
val_steps = val_generator1.samples // batch_size

predictions = model_bp_load.predict(val_generator1, steps=val_steps)

true_labels = val_generator1.classes[:val_steps * batch_size]

num_classes = len(val_generator1.class_indices)
true_labels_one_hot = tf.keras.utils.to_categorical(true_labels, num_classes)

top1_metric = tf.keras.metrics.CategoricalAccuracy()
top5_metric = tf.keras.metrics.TopKCategoricalAccuracy(k=5)
top1_metric.update_state(true_labels_one_hot, predictions)
top5_metric.update_state(true_labels_one_hot, predictions)

print("Top-1 Accuracy on validation set:", top1_metric.result().numpy())
print("Top-5 Accuracy on validation set:", top5_metric.result().numpy())
# Out:
# 61/61 [==============================] - 47s 781ms/step
# Top-1 Accuracy on validation set: 0.8199283
# Top-5 Accuracy on validation set: 0.98155737
