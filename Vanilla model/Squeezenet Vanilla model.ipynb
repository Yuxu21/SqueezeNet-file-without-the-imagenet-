# %%
import keras
import datetime
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import h5py

from tensorflow.keras import Model, Sequential

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Concatenate, Convolution2D, GlobalAveragePooling2D, Layer, Add, MaxPool2D

from keras.callbacks import TensorBoard

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras import regularizers


import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# We import the training and validation data

# %%
train_dir = '../imagenet2/imagenet2/train'
val_dir = '../imagenet2/imagenet2/val'
batch_size=64
def random_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = np.random.randint(0, h - crop_size + 1)
    left = np.random.randint(0, w - crop_size + 1)
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped

train_datagen = ImageDataGenerator(
    rescale=1.,
    horizontal_flip=True,
    preprocessing_function=random_crop_preprocessing
)


def center_crop_preprocessing(img):
    crop_size = 227
    h, w, _ = img.shape
    top = (h - crop_size) // 2
    left = (w - crop_size) // 2
    cropped = img[top:top+crop_size, left:left+crop_size, :]
    mean = np.array([104, 117, 123], dtype=np.float32)
    cropped = cropped - mean
    return cropped

val_datagen = ImageDataGenerator(
    rescale=1.,
    preprocessing_function=center_crop_preprocessing
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator1 = val_datagen.flow_from_directory(
    val_dir,
    target_size=(227, 227),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 9559 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.
# Found 3963 images belonging to 10 classes.

# %% [markdown]
# We define the squeezenet architechture

# %%
one = (1, 1)
two = (2, 2)
three = (3, 3)
five = (5, 5)
seven = (7, 7)
thirteen = (13, 13)

input_shape = (227, 227, 3)
class FireModule(object):

    def __init__(self, layer_number: int, activation: str, kernel_initializer: str) -> None:
        self.layer_number = layer_number
        self.activation = activation
        self.kernel_initializer = kernel_initializer

    def build_module(self, fire_input: Layer) -> Layer:
        global one, three, five

        output_size = 128 * (1 + (self.layer_number//2))

        squeeze_1x1_filters = 16 * (1 + (self.layer_number//2))
        expand_1x1_filters = expand_3x3_filters = output_size//2

        squeeze_1x1 = Conv2D(name=f'fire_{self.layer_number+2}_squeeze_1x1',
            filters=squeeze_1x1_filters, kernel_size=one, strides=1, padding='valid', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(fire_input)
        expand_1x1 = Conv2D(name=f'fire_{self.layer_number+2}_expand_1x1',
            filters=expand_1x1_filters, kernel_size=one, strides=1, padding='valid', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(squeeze_1x1)
        expand_3x3 = Conv2D(name=f'fire_{self.layer_number+2}_expand_3x3',
            filters=expand_3x3_filters, kernel_size=three, strides=1, padding='same', activation=self.activation,
            kernel_initializer=self.kernel_initializer)(squeeze_1x1)

        fire = Concatenate(name=f'fire_{self.layer_number+2}')([expand_1x1, expand_3x3])

        return fire
class SqueezeNet(object):

    def __init__(self, activation: str='relu', kernel_initializer: str='glorot_uniform') -> None:


        self.activation = activation
        self.kernel_initializer = kernel_initializer

    def vanilla_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000) -> None:


        inp = Input(shape=input_shape, name='Input')

        conv_1 = Conv2D(name="Conv_1",
            filters=96, kernel_size=seven, strides=2, padding='same', activation=self.activation, kernel_initializer=self.kernel_initializer)(inp)
        maxpool_1 = MaxPool2D(name="MaxPool_1",
            pool_size=three, strides=2)(conv_1)

        fire_2 = FireModule(layer_number=0, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_1)
        fire_3 = FireModule(layer_number=1, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_2)
        fire_4 = FireModule(layer_number=2, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_3)

        maxpool_2 = MaxPool2D(name="MaxPool_2",
            pool_size=three, strides=2)(fire_4)

        fire_5 = FireModule(layer_number=3, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_2)
        fire_6 = FireModule(layer_number=4, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_5)
        fire_7 = FireModule(layer_number=5, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_6)
        fire_8 = FireModule(layer_number=6, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_7)

        maxpool_3 = MaxPool2D(name="MaxPool_3",
            pool_size=three, strides=2)(fire_8)

        fire_9 = FireModule(layer_number=7, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_3)

        dropout = Dropout(0.5, name="Dropout")(fire_9)

        conv_10 = Conv2D(name="Conv_10",
            filters=10, kernel_size=one, strides=1, padding='valid', activation=self.activation, kernel_initializer=self.kernel_initializer)(dropout)
        gap_11 = GlobalAveragePooling2D()(conv_10)
        out = Activation('softmax', name='softmax')(gap_11)
        self.model = Model(inputs=inp, outputs=out)


    def bypass_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000) -> None:

        inp = Input(shape=input_shape, name='Input')

        conv_1 = Conv2D(name="Conv_1",
            filters=96, kernel_size=seven, strides=2, padding='same', activation=self.activation, kernel_initializer=self.kernel_initializer)(inp)
        maxpool_1 = MaxPool2D(name="MaxPool_1",
            pool_size=three, strides=2)(conv_1)

        fire_2 = FireModule(layer_number=0, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_1)
        fire_3 = FireModule(layer_number=1, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_2)
        bypass_1 = Add(name="Bypass_1")([fire_2, fire_3])
        fire_4 = FireModule(layer_number=2, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(bypass_1)

        maxpool_2 = MaxPool2D(name="MaxPool_2",
            pool_size=three, strides=2)(fire_4)

        fire_5 = FireModule(layer_number=3, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_2)
        bypass_2 = Add(name="Bypass_2")([maxpool_2, fire_5])
        fire_6 = FireModule(layer_number=4, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(bypass_2)
        fire_7 = FireModule(layer_number=5, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(fire_6)
        bypass_3 = Add(name="Bypass_3")([fire_6, fire_7])
        fire_8 = FireModule(layer_number=6, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(bypass_3)

        maxpool_3 = MaxPool2D(name="MaxPool_3",
            pool_size=three, strides=2)(fire_8)

        fire_9 = FireModule(layer_number=7, activation=self.activation, kernel_initializer=self.kernel_initializer).build_module(maxpool_3)
        bypass_4 = Add(name="Bypass_4")([maxpool_3, fire_9])

        dropout = Dropout(0.5, name="Dropout")(bypass_4)

        conv_10 = Conv2D(name="Conv_10",
            filters=10, kernel_size=one, strides=1, padding='valid', activation=self.activation, kernel_initializer=self.kernel_initializer)(dropout)
        gap_11 = GlobalAveragePooling2D()(conv_10)
        out = Activation('softmax', name='softmax')(gap_11)

        self.model = Model(inputs=inp, outputs=out)


    def build_model(self, input_shape: tuple=(224, 224, 3), n_classes: int=1000, choice: str='vanilla') -> Model:
        if choice == "vanilla":
            self.vanilla_model(input_shape, n_classes)
        else:
            self.bypass_model(input_shape, n_classes)

        return self.model

# %% [markdown]
# We set training parameters

# %%
base_lr=0.0003
batch_size=64
steps_per_epoch = train_generator.samples // batch_size
total_epochs = 60
base_lr=0.0003

def poly_lr_scheduler(epoch, lr):
    decay = 1.0 - (epoch / total_epochs)
    new_lr = base_lr * decay
    return new_lr

lr_callback = LearningRateScheduler(poly_lr_scheduler)
tensorboard_callback = TensorBoard(log_dir='./logs')
checkpoint_callback = ModelCheckpoint(
    filepath="squeezenet_checkpoint_epoch_{epoch:02d}.h5",
    save_freq='epoch',
    verbose=1
)

checkpoint_callback = ModelCheckpoint(
    filepath="SqueezeNet_epoch_{epoch:02d}.h5",
    save_freq='epoch',
    verbose=1
)

# %% [markdown]
# We train the model

# %%
sqnet = SqueezeNet()
model_sq = sqnet.build_model(input_shape=input_shape, n_classes=10, choice="vanilla")
model_sq.compile(optimizer= tf.keras.optimizers.Adam(base_lr),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

sq_history = model_sq.fit(
    train_generator,
    epochs=total_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size,
    callbacks=[lr_callback, checkpoint_callback, tensorboard_callback],
    verbose=1
)
# Out:
# Epoch 1/60
# 149/149 [==============================] - ETA: 0s - loss: 2.2377 - accuracy: 0.1588
# Epoch 1: saving model to SqueezeNet_epoch_01.h5
# 149/149 [==============================] - 375s 3s/step - loss: 2.2377 - accuracy: 0.1588 - val_loss: 2.1306 - val_accuracy: 0.2254 - lr: 3.0000e-04
# Epoch 2/60
# 149/149 [==============================] - ETA: 0s - loss: 1.9991 - accuracy: 0.2710
# Epoch 2: saving model to SqueezeNet_epoch_02.h5
# 149/149 [==============================] - 380s 3s/step - loss: 1.9991 - accuracy: 0.2710 - val_loss: 1.9028 - val_accuracy: 0.3348 - lr: 2.9500e-04
# Epoch 3/60
# 149/149 [==============================] - ETA: 0s - loss: 1.8042 - accuracy: 0.3571
# Epoch 3: saving model to SqueezeNet_epoch_03.h5
# 149/149 [==============================] - 378s 3s/step - loss: 1.8042 - accuracy: 0.3571 - val_loss: 1.8016 - val_accuracy: 0.3548 - lr: 2.9000e-04
# Epoch 4/60
# 149/149 [==============================] - ETA: 0s - loss: 1.6945 - accuracy: 0.4085
# Epoch 4: saving model to SqueezeNet_epoch_04.h5
# 149/149 [==============================] - 379s 3s/step - loss: 1.6945 - accuracy: 0.4085 - val_loss: 1.6278 - val_accuracy: 0.4408 - lr: 2.8500e-04
# Epoch 5/60
# 149/149 [==============================] - ETA: 0s - loss: 1.5591 - accuracy: 0.4568
# Epoch 5: saving model to SqueezeNet_epoch_05.h5
# 149/149 [==============================] - 383s 3s/step - loss: 1.5591 - accuracy: 0.4568 - val_loss: 1.4938 - val_accuracy: 0.4887 - lr: 2.8000e-04
# Epoch 6/60
# 149/149 [==============================] - ETA: 0s - loss: 1.4669 - accuracy: 0.4915
# Epoch 6: saving model to SqueezeNet_epoch_06.h5
# 149/149 [==============================] - 439s 3s/step - loss: 1.4669 - accuracy: 0.4915 - val_loss: 1.4824 - val_accuracy: 0.5128 - lr: 2.7500e-04
# Epoch 7/60
# 149/149 [==============================] - ETA: 0s - loss: 1.3789 - accuracy: 0.5231
# Epoch 7: saving model to SqueezeNet_epoch_07.h5
# 149/149 [==============================] - 483s 3s/step - loss: 1.3789 - accuracy: 0.5231 - val_loss: 1.3815 - val_accuracy: 0.5387 - lr: 2.7000e-04
# Epoch 8/60
# 149/149 [==============================] - ETA: 0s - loss: 1.3066 - accuracy: 0.5544
# Epoch 8: saving model to SqueezeNet_epoch_08.h5
# 149/149 [==============================] - 489s 3s/step - loss: 1.3066 - accuracy: 0.5544 - val_loss: 1.4164 - val_accuracy: 0.5318 - lr: 2.6500e-04
# Epoch 9/60
# 149/149 [==============================] - ETA: 0s - loss: 1.2343 - accuracy: 0.5888
# Epoch 9: saving model to SqueezeNet_epoch_09.h5
# 149/149 [==============================] - 433s 3s/step - loss: 1.2343 - accuracy: 0.5888 - val_loss: 1.2707 - val_accuracy: 0.5717 - lr: 2.6000e-04
# Epoch 10/60
# 149/149 [==============================] - ETA: 0s - loss: 1.1413 - accuracy: 0.6221
# Epoch 10: saving model to SqueezeNet_epoch_10.h5
# 149/149 [==============================] - 508s 3s/step - loss: 1.1413 - accuracy: 0.6221 - val_loss: 1.1586 - val_accuracy: 0.6145 - lr: 2.5500e-04
# Epoch 11/60
# 149/149 [==============================] - ETA: 0s - loss: 1.0761 - accuracy: 0.6432
# Epoch 11: saving model to SqueezeNet_epoch_11.h5
# 149/149 [==============================] - 501s 3s/step - loss: 1.0761 - accuracy: 0.6432 - val_loss: 1.1720 - val_accuracy: 0.6117 - lr: 2.5000e-04
# Epoch 12/60
# 149/149 [==============================] - ETA: 0s - loss: 1.0228 - accuracy: 0.6665
# Epoch 12: saving model to SqueezeNet_epoch_12.h5
# 149/149 [==============================] - 704s 5s/step - loss: 1.0228 - accuracy: 0.6665 - val_loss: 1.0544 - val_accuracy: 0.6660 - lr: 2.4500e-04
# Epoch 13/60
# 149/149 [==============================] - ETA: 0s - loss: 0.9861 - accuracy: 0.6815
# Epoch 13: saving model to SqueezeNet_epoch_13.h5
# 149/149 [==============================] - 860s 6s/step - loss: 0.9861 - accuracy: 0.6815 - val_loss: 1.1267 - val_accuracy: 0.6301 - lr: 2.4000e-04
# Epoch 14/60
# 149/149 [==============================] - ETA: 0s - loss: 0.9405 - accuracy: 0.6962
# Epoch 14: saving model to SqueezeNet_epoch_14.h5
# 149/149 [==============================] - 390s 3s/step - loss: 0.9405 - accuracy: 0.6962 - val_loss: 1.0703 - val_accuracy: 0.6660 - lr: 2.3500e-04
# Epoch 15/60
# 149/149 [==============================] - ETA: 0s - loss: 0.8939 - accuracy: 0.7156
# Epoch 15: saving model to SqueezeNet_epoch_15.h5
# 149/149 [==============================] - 391s 3s/step - loss: 0.8939 - accuracy: 0.7156 - val_loss: 1.0419 - val_accuracy: 0.6545 - lr: 2.3000e-04
# Epoch 16/60
# 149/149 [==============================] - ETA: 0s - loss: 0.8987 - accuracy: 0.7042
# Epoch 16: saving model to SqueezeNet_epoch_16.h5
# 149/149 [==============================] - 397s 3s/step - loss: 0.8987 - accuracy: 0.7042 - val_loss: 0.9308 - val_accuracy: 0.7152 - lr: 2.2500e-04
# Epoch 17/60
# 149/149 [==============================] - ETA: 0s - loss: 0.8271 - accuracy: 0.7382
# Epoch 17: saving model to SqueezeNet_epoch_17.h5
# 149/149 [==============================] - 385s 3s/step - loss: 0.8271 - accuracy: 0.7382 - val_loss: 0.9622 - val_accuracy: 0.6934 - lr: 2.2000e-04
# Epoch 18/60
# 149/149 [==============================] - ETA: 0s - loss: 0.7958 - accuracy: 0.7432
# Epoch 18: saving model to SqueezeNet_epoch_18.h5
# 149/149 [==============================] - 383s 3s/step - loss: 0.7958 - accuracy: 0.7432 - val_loss: 0.9391 - val_accuracy: 0.7067 - lr: 2.1500e-04
# Epoch 19/60
# 149/149 [==============================] - ETA: 0s - loss: 0.7829 - accuracy: 0.7542
# Epoch 19: saving model to SqueezeNet_epoch_19.h5
# 149/149 [==============================] - 382s 3s/step - loss: 0.7829 - accuracy: 0.7542 - val_loss: 0.9134 - val_accuracy: 0.7095 - lr: 2.1000e-04
# Epoch 20/60
# 149/149 [==============================] - ETA: 0s - loss: 0.7464 - accuracy: 0.7551
# Epoch 20: saving model to SqueezeNet_epoch_20.h5
# 149/149 [==============================] - 384s 3s/step - loss: 0.7464 - accuracy: 0.7551 - val_loss: 0.9088 - val_accuracy: 0.7218 - lr: 2.0500e-04
# Epoch 21/60
# 149/149 [==============================] - ETA: 0s - loss: 0.7347 - accuracy: 0.7648
# Epoch 21: saving model to SqueezeNet_epoch_21.h5
# 149/149 [==============================] - 407s 3s/step - loss: 0.7347 - accuracy: 0.7648 - val_loss: 0.8084 - val_accuracy: 0.7480 - lr: 2.0000e-04
# Epoch 22/60
# 149/149 [==============================] - ETA: 0s - loss: 0.6719 - accuracy: 0.7854
# Epoch 22: saving model to SqueezeNet_epoch_22.h5
# 149/149 [==============================] - 392s 3s/step - loss: 0.6719 - accuracy: 0.7854 - val_loss: 0.8135 - val_accuracy: 0.7462 - lr: 1.9500e-04
# Epoch 23/60
# 149/149 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.7815
# Epoch 23: saving model to SqueezeNet_epoch_23.h5
# 149/149 [==============================] - 387s 3s/step - loss: 0.6819 - accuracy: 0.7815 - val_loss: 0.8538 - val_accuracy: 0.7295 - lr: 1.9000e-04
# Epoch 24/60
# 149/149 [==============================] - ETA: 0s - loss: 0.6370 - accuracy: 0.7939
# Epoch 24: saving model to SqueezeNet_epoch_24.h5
# 149/149 [==============================] - 378s 3s/step - loss: 0.6370 - accuracy: 0.7939 - val_loss: 0.8820 - val_accuracy: 0.7369 - lr: 1.8500e-04
# Epoch 25/60
# 149/149 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.7954
# Epoch 25: saving model to SqueezeNet_epoch_25.h5
# 149/149 [==============================] - 380s 3s/step - loss: 0.6339 - accuracy: 0.7954 - val_loss: 0.8434 - val_accuracy: 0.7364 - lr: 1.8000e-04
# Epoch 26/60
# 149/149 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.8054
# Epoch 26: saving model to SqueezeNet_epoch_26.h5
# 149/149 [==============================] - 382s 3s/step - loss: 0.6048 - accuracy: 0.8054 - val_loss: 0.8357 - val_accuracy: 0.7515 - lr: 1.7500e-04
# Epoch 27/60
# 149/149 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.8051
# Epoch 27: saving model to SqueezeNet_epoch_27.h5
# 149/149 [==============================] - 408s 3s/step - loss: 0.5996 - accuracy: 0.8051 - val_loss: 0.7950 - val_accuracy: 0.7582 - lr: 1.7000e-04
# Epoch 28/60
# 149/149 [==============================] - ETA: 0s - loss: 0.5787 - accuracy: 0.8128
# Epoch 28: saving model to SqueezeNet_epoch_28.h5
# 149/149 [==============================] - 383s 3s/step - loss: 0.5787 - accuracy: 0.8128 - val_loss: 0.7891 - val_accuracy: 0.7602 - lr: 1.6500e-04
# Epoch 29/60
# 149/149 [==============================] - ETA: 0s - loss: 0.5534 - accuracy: 0.8224
# Epoch 29: saving model to SqueezeNet_epoch_29.h5
# 149/149 [==============================] - 667s 4s/step - loss: 0.5534 - accuracy: 0.8224 - val_loss: 0.7990 - val_accuracy: 0.7523 - lr: 1.6000e-04
# Epoch 30/60
# 149/149 [==============================] - ETA: 0s - loss: 0.5356 - accuracy: 0.8296
# Epoch 30: saving model to SqueezeNet_epoch_30.h5
# 149/149 [==============================] - 743s 5s/step - loss: 0.5356 - accuracy: 0.8296 - val_loss: 0.8738 - val_accuracy: 0.7464 - lr: 1.5500e-04
# Epoch 31/60
# 149/149 [==============================] - ETA: 0s - loss: 0.5166 - accuracy: 0.8344
# Epoch 31: saving model to SqueezeNet_epoch_31.h5
# 149/149 [==============================] - 532s 4s/step - loss: 0.5166 - accuracy: 0.8344 - val_loss: 0.8422 - val_accuracy: 0.7462 - lr: 1.5000e-04
# Epoch 32/60
# 149/149 [==============================] - ETA: 0s - loss: 0.4992 - accuracy: 0.8391
# Epoch 32: saving model to SqueezeNet_epoch_32.h5
# 149/149 [==============================] - 1103s 7s/step - loss: 0.4992 - accuracy: 0.8391 - val_loss: 0.7607 - val_accuracy: 0.7656 - lr: 1.4500e-04
# Epoch 33/60
# 149/149 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 0.8458
# Epoch 33: saving model to SqueezeNet_epoch_33.h5
# 149/149 [==============================] - 472s 3s/step - loss: 0.4826 - accuracy: 0.8458 - val_loss: 0.8198 - val_accuracy: 0.7610 - lr: 1.4000e-04
# Epoch 34/60
# 149/149 [==============================] - ETA: 0s - loss: 0.4685 - accuracy: 0.8499
# Epoch 34: saving model to SqueezeNet_epoch_34.h5
# 149/149 [==============================] - 471s 3s/step - loss: 0.4685 - accuracy: 0.8499 - val_loss: 0.8072 - val_accuracy: 0.7613 - lr: 1.3500e-04
# Epoch 35/60
# 149/149 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.8554
# Epoch 35: saving model to SqueezeNet_epoch_35.h5
# 149/149 [==============================] - 717s 5s/step - loss: 0.4461 - accuracy: 0.8554 - val_loss: 0.7940 - val_accuracy: 0.7687 - lr: 1.3000e-04
# Epoch 36/60
# 149/149 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.8568
# Epoch 36: saving model to SqueezeNet_epoch_36.h5
# 149/149 [==============================] - 568s 4s/step - loss: 0.4428 - accuracy: 0.8568 - val_loss: 0.7853 - val_accuracy: 0.7649 - lr: 1.2500e-04
# Epoch 37/60
# 149/149 [==============================] - ETA: 0s - loss: 0.4227 - accuracy: 0.8605
# Epoch 37: saving model to SqueezeNet_epoch_37.h5
# 149/149 [==============================] - 566s 4s/step - loss: 0.4227 - accuracy: 0.8605 - val_loss: 0.7821 - val_accuracy: 0.7638 - lr: 1.2000e-04
# Epoch 38/60
# 149/149 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.8639
# Epoch 38: saving model to SqueezeNet_epoch_38.h5
# 149/149 [==============================] - 711s 5s/step - loss: 0.4161 - accuracy: 0.8639 - val_loss: 0.7660 - val_accuracy: 0.7697 - lr: 1.1500e-04
# Epoch 39/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3918 - accuracy: 0.8753
# Epoch 39: saving model to SqueezeNet_epoch_39.h5
# 149/149 [==============================] - 872s 6s/step - loss: 0.3918 - accuracy: 0.8753 - val_loss: 0.8187 - val_accuracy: 0.7679 - lr: 1.1000e-04
# Epoch 40/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3756 - accuracy: 0.8797
# Epoch 40: saving model to SqueezeNet_epoch_40.h5
# 149/149 [==============================] - 739s 5s/step - loss: 0.3756 - accuracy: 0.8797 - val_loss: 0.8284 - val_accuracy: 0.7666 - lr: 1.0500e-04
# Epoch 41/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3749 - accuracy: 0.8784
# Epoch 41: saving model to SqueezeNet_epoch_41.h5
# 149/149 [==============================] - 499s 3s/step - loss: 0.3749 - accuracy: 0.8784 - val_loss: 0.8100 - val_accuracy: 0.7687 - lr: 1.0000e-04
# Epoch 42/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.8868
# Epoch 42: saving model to SqueezeNet_epoch_42.h5
# 149/149 [==============================] - 392s 3s/step - loss: 0.3502 - accuracy: 0.8868 - val_loss: 0.8683 - val_accuracy: 0.7641 - lr: 9.5000e-05
# Epoch 43/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.8911
# Epoch 43: saving model to SqueezeNet_epoch_43.h5
# 149/149 [==============================] - 401s 3s/step - loss: 0.3380 - accuracy: 0.8911 - val_loss: 0.8357 - val_accuracy: 0.7669 - lr: 9.0000e-05
# Epoch 44/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8934
# Epoch 44: saving model to SqueezeNet_epoch_44.h5
# 149/149 [==============================] - 404s 3s/step - loss: 0.3329 - accuracy: 0.8934 - val_loss: 0.7869 - val_accuracy: 0.7802 - lr: 8.5000e-05
# Epoch 45/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3105 - accuracy: 0.9017
# Epoch 45: saving model to SqueezeNet_epoch_45.h5
# 149/149 [==============================] - 423s 3s/step - loss: 0.3105 - accuracy: 0.9017 - val_loss: 0.8289 - val_accuracy: 0.7651 - lr: 8.0000e-05
# Epoch 46/60
# 149/149 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.9045
# Epoch 46: saving model to SqueezeNet_epoch_46.h5
# 149/149 [==============================] - 395s 3s/step - loss: 0.3023 - accuracy: 0.9045 - val_loss: 0.9491 - val_accuracy: 0.7536 - lr: 7.5000e-05
# Epoch 47/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2963 - accuracy: 0.9076
# Epoch 47: saving model to SqueezeNet_epoch_47.h5
# 149/149 [==============================] - 389s 3s/step - loss: 0.2963 - accuracy: 0.9076 - val_loss: 0.8627 - val_accuracy: 0.7751 - lr: 7.0000e-05
# Epoch 48/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.9124
# Epoch 48: saving model to SqueezeNet_epoch_48.h5
# 149/149 [==============================] - 414s 3s/step - loss: 0.2798 - accuracy: 0.9124 - val_loss: 0.8566 - val_accuracy: 0.7695 - lr: 6.5000e-05
# Epoch 49/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.9162
# Epoch 49: saving model to SqueezeNet_epoch_49.h5
# 149/149 [==============================] - 425s 3s/step - loss: 0.2657 - accuracy: 0.9162 - val_loss: 0.9035 - val_accuracy: 0.7697 - lr: 6.0000e-05
# Epoch 50/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.9183
# Epoch 50: saving model to SqueezeNet_epoch_50.h5
# 149/149 [==============================] - 433s 3s/step - loss: 0.2599 - accuracy: 0.9183 - val_loss: 0.9342 - val_accuracy: 0.7682 - lr: 5.5000e-05
# Epoch 51/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9233
# Epoch 51: saving model to SqueezeNet_epoch_51.h5
# 149/149 [==============================] - 431s 3s/step - loss: 0.2445 - accuracy: 0.9233 - val_loss: 0.9042 - val_accuracy: 0.7723 - lr: 5.0000e-05
# Epoch 52/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.9294
# Epoch 52: saving model to SqueezeNet_epoch_52.h5
# 149/149 [==============================] - 426s 3s/step - loss: 0.2328 - accuracy: 0.9294 - val_loss: 0.8964 - val_accuracy: 0.7751 - lr: 4.5000e-05
# Epoch 53/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9350
# Epoch 53: saving model to SqueezeNet_epoch_53.h5
# 149/149 [==============================] - 443s 3s/step - loss: 0.2160 - accuracy: 0.9350 - val_loss: 0.9150 - val_accuracy: 0.7736 - lr: 4.0000e-05
# Epoch 54/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9365
# Epoch 54: saving model to SqueezeNet_epoch_54.h5
# 149/149 [==============================] - 437s 3s/step - loss: 0.2075 - accuracy: 0.9365 - val_loss: 0.9391 - val_accuracy: 0.7784 - lr: 3.5000e-05
# Epoch 55/60
# 149/149 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9380
# Epoch 55: saving model to SqueezeNet_epoch_55.h5
# 149/149 [==============================] - 429s 3s/step - loss: 0.2016 - accuracy: 0.9380 - val_loss: 0.9518 - val_accuracy: 0.7687 - lr: 3.0000e-05
# Epoch 56/60
# 149/149 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9389
# Epoch 56: saving model to SqueezeNet_epoch_56.h5
# 149/149 [==============================] - 422s 3s/step - loss: 0.1994 - accuracy: 0.9389 - val_loss: 0.9344 - val_accuracy: 0.7728 - lr: 2.5000e-05
# Epoch 57/60
# 149/149 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9401
# Epoch 57: saving model to SqueezeNet_epoch_57.h5
# 149/149 [==============================] - 428s 3s/step - loss: 0.1909 - accuracy: 0.9401 - val_loss: 0.9597 - val_accuracy: 0.7736 - lr: 2.0000e-05
# Epoch 58/60
# 149/149 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9453
# Epoch 58: saving model to SqueezeNet_epoch_58.h5
# 149/149 [==============================] - 420s 3s/step - loss: 0.1821 - accuracy: 0.9453 - val_loss: 0.9634 - val_accuracy: 0.7715 - lr: 1.5000e-05
# Epoch 59/60
# 149/149 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9498
# Epoch 59: saving model to SqueezeNet_epoch_59.h5
# 149/149 [==============================] - 428s 3s/step - loss: 0.1715 - accuracy: 0.9498 - val_loss: 0.9698 - val_accuracy: 0.7779 - lr: 1.0000e-05
# Epoch 60/60
# 149/149 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9496
# Epoch 60: saving model to SqueezeNet_epoch_60.h5
# 149/149 [==============================] - 433s 3s/step - loss: 0.1672 - accuracy: 0.9496 - val_loss: 0.9641 - val_accuracy: 0.7733 - lr: 5.0000e-06

# %%
model_sq.save_weights('Squeeze_net.h5')

# %%
sqnet = SqueezeNet()
model_bp_load = sqnet.build_model(input_shape=input_shape, n_classes=10, choice="vanilla")
model_bp_load.load_weights('Squeeze_net.h5')

# %% [markdown]
# We verify the accuracy

# %%
val_steps = val_generator1.samples // batch_size

predictions = model_bp_load.predict(val_generator1, steps=val_steps)

true_labels = val_generator1.classes[:val_steps * batch_size]

num_classes = len(val_generator1.class_indices)
true_labels_one_hot = tf.keras.utils.to_categorical(true_labels, num_classes)

top1_metric = tf.keras.metrics.CategoricalAccuracy()
top5_metric = tf.keras.metrics.TopKCategoricalAccuracy(k=5)
top1_metric.update_state(true_labels_one_hot, predictions)
top5_metric.update_state(true_labels_one_hot, predictions)

print("Top-1 Accuracy on validation set:", top1_metric.result().numpy())
print("Top-5 Accuracy on validation set:", top5_metric.result().numpy())
# Out:
# 61/61 [==============================] - 68s 1s/step
# Top-1 Accuracy on validation set: 0.77612704
# Top-5 Accuracy on validation set: 0.9707992

# %%
model_sq.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 227, 227, 3  0           []
#                                 )]
#
#  Conv_1 (Conv2D)                (None, 114, 114, 96  14208       ['Input[0][0]']
#                                 )
#
#  MaxPool_1 (MaxPooling2D)       (None, 56, 56, 96)   0           ['Conv_1[0][0]']
#
#  fire_2_squeeze_1x1 (Conv2D)    (None, 56, 56, 16)   1552        ['MaxPool_1[0][0]']
#
#  fire_2_expand_1x1 (Conv2D)     (None, 56, 56, 64)   1088        ['fire_2_squeeze_1x1[0][0]']
#
#  fire_2_expand_3x3 (Conv2D)     (None, 56, 56, 64)   9280        ['fire_2_squeeze_1x1[0][0]']
#
#  fire_2 (Concatenate)           (None, 56, 56, 128)  0           ['fire_2_expand_1x1[0][0]',
#                                                                   'fire_2_expand_3x3[0][0]']
#
#  fire_3_squeeze_1x1 (Conv2D)    (None, 56, 56, 16)   2064        ['fire_2[0][0]']
#
#  fire_3_expand_1x1 (Conv2D)     (None, 56, 56, 64)   1088        ['fire_3_squeeze_1x1[0][0]']
#
#  fire_3_expand_3x3 (Conv2D)     (None, 56, 56, 64)   9280        ['fire_3_squeeze_1x1[0][0]']
#
#  fire_3 (Concatenate)           (None, 56, 56, 128)  0           ['fire_3_expand_1x1[0][0]',
#                                                                   'fire_3_expand_3x3[0][0]']
#
#  fire_4_squeeze_1x1 (Conv2D)    (None, 56, 56, 32)   4128        ['fire_3[0][0]']
#
#  fire_4_expand_1x1 (Conv2D)     (None, 56, 56, 128)  4224        ['fire_4_squeeze_1x1[0][0]']
#
#  fire_4_expand_3x3 (Conv2D)     (None, 56, 56, 128)  36992       ['fire_4_squeeze_1x1[0][0]']
#
#  fire_4 (Concatenate)           (None, 56, 56, 256)  0           ['fire_4_expand_1x1[0][0]',
#                                                                   'fire_4_expand_3x3[0][0]']
#
#  MaxPool_2 (MaxPooling2D)       (None, 27, 27, 256)  0           ['fire_4[0][0]']
#
#  fire_5_squeeze_1x1 (Conv2D)    (None, 27, 27, 32)   8224        ['MaxPool_2[0][0]']
#
#  fire_5_expand_1x1 (Conv2D)     (None, 27, 27, 128)  4224        ['fire_5_squeeze_1x1[0][0]']
#
#  fire_5_expand_3x3 (Conv2D)     (None, 27, 27, 128)  36992       ['fire_5_squeeze_1x1[0][0]']
#
#  fire_5 (Concatenate)           (None, 27, 27, 256)  0           ['fire_5_expand_1x1[0][0]',
#                                                                   'fire_5_expand_3x3[0][0]']
#
#  fire_6_squeeze_1x1 (Conv2D)    (None, 27, 27, 48)   12336       ['fire_5[0][0]']
#
#  fire_6_expand_1x1 (Conv2D)     (None, 27, 27, 192)  9408        ['fire_6_squeeze_1x1[0][0]']
#
#  fire_6_expand_3x3 (Conv2D)     (None, 27, 27, 192)  83136       ['fire_6_squeeze_1x1[0][0]']
#
#  fire_6 (Concatenate)           (None, 27, 27, 384)  0           ['fire_6_expand_1x1[0][0]',
#                                                                   'fire_6_expand_3x3[0][0]']
#
#  fire_7_squeeze_1x1 (Conv2D)    (None, 27, 27, 48)   18480       ['fire_6[0][0]']
#
#  fire_7_expand_1x1 (Conv2D)     (None, 27, 27, 192)  9408        ['fire_7_squeeze_1x1[0][0]']
#
#  fire_7_expand_3x3 (Conv2D)     (None, 27, 27, 192)  83136       ['fire_7_squeeze_1x1[0][0]']
#
#  fire_7 (Concatenate)           (None, 27, 27, 384)  0           ['fire_7_expand_1x1[0][0]',
#                                                                   'fire_7_expand_3x3[0][0]']
#
#  fire_8_squeeze_1x1 (Conv2D)    (None, 27, 27, 64)   24640       ['fire_7[0][0]']
#
#  fire_8_expand_1x1 (Conv2D)     (None, 27, 27, 256)  16640       ['fire_8_squeeze_1x1[0][0]']
#
#  fire_8_expand_3x3 (Conv2D)     (None, 27, 27, 256)  147712      ['fire_8_squeeze_1x1[0][0]']
#
#  fire_8 (Concatenate)           (None, 27, 27, 512)  0           ['fire_8_expand_1x1[0][0]',
#                                                                   'fire_8_expand_3x3[0][0]']
#
#  MaxPool_3 (MaxPooling2D)       (None, 13, 13, 512)  0           ['fire_8[0][0]']
#
#  fire_9_squeeze_1x1 (Conv2D)    (None, 13, 13, 64)   32832       ['MaxPool_3[0][0]']
#
#  fire_9_expand_1x1 (Conv2D)     (None, 13, 13, 256)  16640       ['fire_9_squeeze_1x1[0][0]']
#
#  fire_9_expand_3x3 (Conv2D)     (None, 13, 13, 256)  147712      ['fire_9_squeeze_1x1[0][0]']
#
#  fire_9 (Concatenate)           (None, 13, 13, 512)  0           ['fire_9_expand_1x1[0][0]',
#                                                                   'fire_9_expand_3x3[0][0]']
#
#  Dropout (Dropout)              (None, 13, 13, 512)  0           ['fire_9[0][0]']
#
#  Conv_10 (Conv2D)               (None, 13, 13, 10)   5130        ['Dropout[0][0]']
#
#  global_average_pooling2d (Glob  (None, 10)          0           ['Conv_10[0][0]']
#  alAveragePooling2D)
#
#  softmax (Activation)           (None, 10)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 740,554
# Trainable params: 740,554
# Non-trainable params: 0
# __________________________________________________________________________________________________
